# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## 1. Preprocessing

# %%
data = pd.read_csv("data_train.csv")

# %%
data['time_entry'] = pd.to_datetime(data['time_entry'], format='%H:%M:%S')
data['time_exit']  = pd.to_datetime(data['time_exit'], format='%H:%M:%S')

# %%
data['duration'] = (data['time_exit'] - data['time_entry']).dt.total_seconds().astype(int)

# %%
data = data[data['time_exit'].dt.hour.between(15,16)]

# %%
data[:5]
# Out:
#     Unnamed: 0                                 hash  \
# 5            5   0000a8602cf2def930488dee7cdad104_1
# 9            9   0000cf177130469eeac79f67b6bcf3df_9
# 11          11   0001f97b99a80f18f62e2d44e54ef33d_3
# 20          20  0002124248b0ca510dea42824723ccac_31
# 28          28  000219c2a6380c307e8bffd85b5e404b_23
#
#                                   trajectory_id          time_entry  \
# 5     traj_0000a8602cf2def930488dee7cdad104_1_5 1900-01-01 15:02:31
# 9     traj_0000cf177130469eeac79f67b6bcf3df_9_3 1900-01-01 15:00:32
# 11    traj_0001f97b99a80f18f62e2d44e54ef33d_3_1 1900-01-01 14:34:35
# 20  traj_0002124248b0ca510dea42824723ccac_31_10 1900-01-01 15:28:54
# 28  traj_000219c2a6380c307e8bffd85b5e404b_23_16 1900-01-01 15:08:05
#
#              time_exit       vmax       vmin      vmean       x_entry  \
# 5  1900-01-01 15:18:33        NaN        NaN        NaN  3.744945e+06
# 9  1900-01-01 15:29:48   1.149404   1.149404   1.149404  3.749088e+06
# 11 1900-01-01 15:19:51  30.167742  30.167742  30.167742  3.758738e+06
# 20 1900-01-01 15:28:54        NaN        NaN        NaN  3.767866e+06
# 28 1900-01-01 15:08:05        NaN        NaN        NaN  3.747641e+06
#
#          y_entry        x_exit        y_exit  duration
# 5  -1.928183e+07  3.744785e+06 -1.928148e+07       962
# 9  -1.926605e+07  3.749610e+06 -1.926594e+07      1756
# 11 -1.937594e+07  3.769687e+06 -1.914258e+07      2716
# 20 -1.917797e+07  3.767866e+06 -1.917797e+07         0
# 28 -1.922695e+07  3.747641e+06 -1.922695e+07         0

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# might neet larger range(15) for test data
entryHEnc = OneHotEncoder(sparse=False, dtype=bool)
hour = entryHEnc.fit_transform(data['time_entry'].dt.hour.values.reshape(-1,1))
data = pd.concat([data, pd.DataFrame(hour, columns=['hour_'+str(entryHEnc.active_features_[n]) for n in range(hour.shape[1])], 
                                      index=data.index)], axis=1)
entryMEnc = OneHotEncoder(sparse=False, dtype=bool)
minute = entryMEnc.fit_transform(data['time_entry'].dt.minute.values.reshape(-1,1))
data = pd.concat([data, pd.DataFrame(minute, columns=['minute_'+str(entryMEnc.active_features_[n]) for n in range(minute.shape[1])], 
                                      index=data.index)], axis=1)

# %%
exitHEnc = OneHotEncoder(sparse=False, dtype=bool)
ehour = exitHEnc.fit_transform(data['time_exit'].dt.hour.values.reshape(-1,1))
data = pd.concat([data, pd.DataFrame(ehour, columns=['ehour_'+str(exitHEnc.active_features_[n]) for n in range(ehour.shape[1])], 
                                      index=data.index)], axis=1)
exitMEnc = OneHotEncoder(sparse=False, dtype=bool)
eminute = exitMEnc.fit_transform(data['time_exit'].dt.minute.values.reshape(-1,1))
data = pd.concat([data, pd.DataFrame(eminute, columns=['eminute_'+str(exitMEnc.active_features_[n]) for n in range(minute.shape[1])], 
                                      index=data.index)], axis=1)

# %%
Y = data['x_exit'].between(3750901.5068, 3770901.5068) & data['y_exit'].between((-19268905.6133), -19208905.6133)

# %%
X = data.drop(['Unnamed: 0', 'hash', 'trajectory_id', 'time_entry', 'time_exit', 'x_exit', 'y_exit'], axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
train_x.shape
# Out:
# (107250, 135)

# %% [markdown]
# # Model Building

# %%
models = xgb.XGBClassifier(max_depth=10, learning_rate=0.03, n_estimators=20000, n_jobs=-1,
                           subsample=0.8, colsample_bytree=0.8, seed=420)

# %%
models.fit(train_x, train_y, eval_metric='auc', early_stopping_rounds=100,
           eval_set=[(train_x, train_y), (test_x, test_y)])
# Out:
# [0]	validation_0-auc:0.538435	validation_1-auc:0.52464
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.831303	validation_1-auc:0.808397
# [2]	validation_0-auc:0.96329	validation_1-auc:0.951391
# [3]	validation_0-auc:0.970477	validation_1-auc:0.960032
# [4]	validation_0-auc:0.964767	validation_1-auc:0.951535
# [5]	validation_0-auc:0.959134	validation_1-auc:0.945946
# [6]	validation_0-auc:0.967465	validation_1-auc:0.954902
# [7]	validation_0-auc:0.972002	validation_1-auc:0.959983
# [8]	validation_0-auc:0.974976	validation_1-auc:0.963218
# [9]	validation_0-auc:0.972362	validation_1-auc:0.95954
# [10]	validation_0-auc:0.974974	validation_1-auc:0.96258
# [11]	validation_0-auc:0.976819	validation_1-auc:0.964774
# [12]	validation_0-auc:0.978118	validation_1-auc:0.966575
# [13]	validation_0-auc:0.978476	validation_1-auc:0.96726
# [14]	validation_0-auc:0.979291	validation_1-auc:0.968248
# [15]	validation_0-auc:0.980116	validation_1-auc:0.969393
# [16]	validation_0-auc:0.98077	validation_1-auc:0.970294
# [17]	validation_0-auc:0.981344	validation_1-auc:0.971059
# [18]	validation_0-auc:0.981453	validation_1-auc:0.97131
# [19]	validation_0-auc:0.98126	validation_1-auc:0.971233
# [20]	validation_0-auc:0.981162	validation_1-auc:0.971147
# [21]	validation_0-auc:0.981223	validation_1-auc:0.971308
# [22]	validation_0-auc:0.981719	validation_1-auc:0.972096
# [23]	validation_0-auc:0.982095	validation_1-auc:0.972733
# [24]	validation_0-auc:0.981935	validation_1-auc:0.971978
# [25]	validation_0-auc:0.981634	validation_1-auc:0.971125
# [26]	validation_0-auc:0.981694	validation_1-auc:0.971275
# [27]	validation_0-auc:0.981627	validation_1-auc:0.971266
# [28]	validation_0-auc:0.981539	validation_1-auc:0.971217
# [29]	validation_0-auc:0.981965	validation_1-auc:0.971831
# [30]	validation_0-auc:0.982346	validation_1-auc:0.972264
# [31]	validation_0-auc:0.982449	validation_1-auc:0.97244
# [32]	validation_0-auc:0.982458	validation_1-auc:0.972507
# [33]	validation_0-auc:0.982537	validation_1-auc:0.972588
# [34]	validation_0-auc:0.982445	validation_1-auc:0.972541
# [35]	validation_0-auc:0.982772	validation_1-auc:0.973051
# [36]	validation_0-auc:0.982821	validation_1-auc:0.973021
# [37]	validation_0-auc:0.982883	validation_1-auc:0.97309
# [38]	validation_0-auc:0.982598	validation_1-auc:0.972796
# [39]	validation_0-auc:0.982673	validation_1-auc:0.972568
# [40]	validation_0-auc:0.982705	validation_1-auc:0.972591
# [41]	validation_0-auc:0.983032	validation_1-auc:0.973041
# [42]	validation_0-auc:0.98338	validation_1-auc:0.973439
# [43]	validation_0-auc:0.983432	validation_1-auc:0.973518
# [44]	validation_0-auc:0.983692	validation_1-auc:0.973938
# [45]	validation_0-auc:0.983749	validation_1-auc:0.973745
# [46]	validation_0-auc:0.983698	validation_1-auc:0.973696
# [47]	validation_0-auc:0.983751	validation_1-auc:0.973787
# [48]	validation_0-auc:0.983993	validation_1-auc:0.974087
# [49]	validation_0-auc:0.984212	validation_1-auc:0.974404
# [50]	validation_0-auc:0.984431	validation_1-auc:0.974701
# [51]	validation_0-auc:0.984618	validation_1-auc:0.974973
# [52]	validation_0-auc:0.984766	validation_1-auc:0.975197
# [53]	validation_0-auc:0.984914	validation_1-auc:0.975448
# [54]	validation_0-auc:0.985064	validation_1-auc:0.975641
# [55]	validation_0-auc:0.985062	validation_1-auc:0.975596
# [56]	validation_0-auc:0.985092	validation_1-auc:0.975604
# [57]	validation_0-auc:0.985202	validation_1-auc:0.975807
# [58]	validation_0-auc:0.985334	validation_1-auc:0.975958
# [59]	validation_0-auc:0.985457	validation_1-auc:0.976111
# [60]	validation_0-auc:0.985587	validation_1-auc:0.976279
# [61]	validation_0-auc:0.985627	validation_1-auc:0.976234
# [62]	validation_0-auc:0.985719	validation_1-auc:0.97641
# [63]	validation_0-auc:0.985737	validation_1-auc:0.976364
# [64]	validation_0-auc:0.985829	validation_1-auc:0.976518
# [65]	validation_0-auc:0.985872	validation_1-auc:0.976491
# [66]	validation_0-auc:0.985949	validation_1-auc:0.976624
# [67]	validation_0-auc:0.986041	validation_1-auc:0.976775
# [68]	validation_0-auc:0.986146	validation_1-auc:0.976924
# [69]	validation_0-auc:0.98625	validation_1-auc:0.977028
# [70]	validation_0-auc:0.986214	validation_1-auc:0.976954
# [71]	validation_0-auc:0.986309	validation_1-auc:0.977072
# [72]	validation_0-auc:0.986386	validation_1-auc:0.977181
# [73]	validation_0-auc:0.986451	validation_1-auc:0.977277
# [74]	validation_0-auc:0.986519	validation_1-auc:0.977326
# [75]	validation_0-auc:0.986538	validation_1-auc:0.97729
# [76]	validation_0-auc:0.986544	validation_1-auc:0.977296
# [77]	validation_0-auc:0.986596	validation_1-auc:0.977397
# [78]	validation_0-auc:0.986661	validation_1-auc:0.977496
# [79]	validation_0-auc:0.986681	validation_1-auc:0.977464
# [80]	validation_0-auc:0.986757	validation_1-auc:0.977548
# [81]	validation_0-auc:0.986784	validation_1-auc:0.97753
# [82]	validation_0-auc:0.986855	validation_1-auc:0.97761
# [83]	validation_0-auc:0.986922	validation_1-auc:0.977685
# [84]	validation_0-auc:0.986962	validation_1-auc:0.977743
# [85]	validation_0-auc:0.986999	validation_1-auc:0.977796
# [86]	validation_0-auc:0.987051	validation_1-auc:0.977859
# [87]	validation_0-auc:0.987062	validation_1-auc:0.97784
# [88]	validation_0-auc:0.987082	validation_1-auc:0.977816
# [89]	validation_0-auc:0.987102	validation_1-auc:0.97782
# [90]	validation_0-auc:0.98714	validation_1-auc:0.977887
# [91]	validation_0-auc:0.987195	validation_1-auc:0.97789
# [92]	validation_0-auc:0.987205	validation_1-auc:0.977883
# [93]	validation_0-auc:0.987244	validation_1-auc:0.977878
# [94]	validation_0-auc:0.987309	validation_1-auc:0.977925
# [95]	validation_0-auc:0.987359	validation_1-auc:0.977969
# [96]	validation_0-auc:0.987376	validation_1-auc:0.977971
# [97]	validation_0-auc:0.987389	validation_1-auc:0.977975
# [98]	validation_0-auc:0.987374	validation_1-auc:0.977942
# [99]	validation_0-auc:0.987435	validation_1-auc:0.97799
# [100]	validation_0-auc:0.987453	validation_1-auc:0.977983
# [101]	validation_0-auc:0.987477	validation_1-auc:0.977974
# [102]	validation_0-auc:0.987515	validation_1-auc:0.977984
# [103]	validation_0-auc:0.987556	validation_1-auc:0.977992
# [104]	validation_0-auc:0.987606	validation_1-auc:0.978041
# [105]	validation_0-auc:0.987648	validation_1-auc:0.978071
# [106]	validation_0-auc:0.987664	validation_1-auc:0.978079
# [107]	validation_0-auc:0.987691	validation_1-auc:0.978087
# [108]	validation_0-auc:0.987731	validation_1-auc:0.978094
# [109]	validation_0-auc:0.987778	validation_1-auc:0.978161
# [110]	validation_0-auc:0.987824	validation_1-auc:0.978197
# [111]	validation_0-auc:0.987859	validation_1-auc:0.97823
# [112]	validation_0-auc:0.987872	validation_1-auc:0.978218
# [113]	validation_0-auc:0.987904	validation_1-auc:0.978228
# [114]	validation_0-auc:0.987925	validation_1-auc:0.978216
# [115]	validation_0-auc:0.987969	validation_1-auc:0.978268
# [116]	validation_0-auc:0.988011	validation_1-auc:0.978288
# [117]	validation_0-auc:0.988022	validation_1-auc:0.978289
# [118]	validation_0-auc:0.988062	validation_1-auc:0.978333
# [119]	validation_0-auc:0.988107	validation_1-auc:0.978365
# [120]	validation_0-auc:0.988149	validation_1-auc:0.978384
# [121]	validation_0-auc:0.988177	validation_1-auc:0.978401
# [122]	validation_0-auc:0.988209	validation_1-auc:0.978443
# [123]	validation_0-auc:0.988216	validation_1-auc:0.978447
# [124]	validation_0-auc:0.988251	validation_1-auc:0.978449
# [125]	validation_0-auc:0.98826	validation_1-auc:0.978459
# [126]	validation_0-auc:0.988304	validation_1-auc:0.978481
# [127]	validation_0-auc:0.98833	validation_1-auc:0.978492
# [128]	validation_0-auc:0.988347	validation_1-auc:0.978495
# [129]	validation_0-auc:0.988388	validation_1-auc:0.978519
# [130]	validation_0-auc:0.988417	validation_1-auc:0.978533
# [131]	validation_0-auc:0.988456	validation_1-auc:0.978578
# [132]	validation_0-auc:0.988498	validation_1-auc:0.978611
# [133]	validation_0-auc:0.98852	validation_1-auc:0.978611
# [134]	validation_0-auc:0.98853	validation_1-auc:0.978617
# [135]	validation_0-auc:0.988541	validation_1-auc:0.978627
# [136]	validation_0-auc:0.988566	validation_1-auc:0.978628
# [137]	validation_0-auc:0.988599	validation_1-auc:0.978646
# [138]	validation_0-auc:0.98864	validation_1-auc:0.978667
# [139]	validation_0-auc:0.988679	validation_1-auc:0.978689
# [140]	validation_0-auc:0.988692	validation_1-auc:0.978683
# [141]	validation_0-auc:0.988712	validation_1-auc:0.978684
# [142]	validation_0-auc:0.988746	validation_1-auc:0.978694
# [143]	validation_0-auc:0.988766	validation_1-auc:0.978699
# [144]	validation_0-auc:0.988785	validation_1-auc:0.978706
# [145]	validation_0-auc:0.988799	validation_1-auc:0.978706
# [146]	validation_0-auc:0.988829	validation_1-auc:0.978729
# [147]	validation_0-auc:0.988863	validation_1-auc:0.97875
# [148]	validation_0-auc:0.988888	validation_1-auc:0.978772
# [149]	validation_0-auc:0.988919	validation_1-auc:0.978786
# [150]	validation_0-auc:0.988942	validation_1-auc:0.978816
# [151]	validation_0-auc:0.988967	validation_1-auc:0.978807
# [152]	validation_0-auc:0.989	validation_1-auc:0.978836
# [153]	validation_0-auc:0.989033	validation_1-auc:0.978854
# [154]	validation_0-auc:0.989055	validation_1-auc:0.978866
# [155]	validation_0-auc:0.989069	validation_1-auc:0.97886
# [156]	validation_0-auc:0.989084	validation_1-auc:0.978863
# [157]	validation_0-auc:0.989101	validation_1-auc:0.978862
# [158]	validation_0-auc:0.989129	validation_1-auc:0.978881
# [159]	validation_0-auc:0.989164	validation_1-auc:0.978898
# [160]	validation_0-auc:0.989191	validation_1-auc:0.978898
# [161]	validation_0-auc:0.989221	validation_1-auc:0.978904
# [162]	validation_0-auc:0.989256	validation_1-auc:0.978924
# [163]	validation_0-auc:0.989272	validation_1-auc:0.97893
# [164]	validation_0-auc:0.989278	validation_1-auc:0.978925
# [165]	validation_0-auc:0.989289	validation_1-auc:0.978924
# [166]	validation_0-auc:0.98931	validation_1-auc:0.97893
# [167]	validation_0-auc:0.989337	validation_1-auc:0.978935
# [168]	validation_0-auc:0.989368	validation_1-auc:0.978946
# [169]	validation_0-auc:0.989387	validation_1-auc:0.978945
# [170]	validation_0-auc:0.989393	validation_1-auc:0.978945
# [171]	validation_0-auc:0.989407	validation_1-auc:0.978951
# [172]	validation_0-auc:0.98942	validation_1-auc:0.978952
# [173]	validation_0-auc:0.989436	validation_1-auc:0.978964
# [174]	validation_0-auc:0.989464	validation_1-auc:0.978981
# [175]	validation_0-auc:0.989475	validation_1-auc:0.978975
# [176]	validation_0-auc:0.989492	validation_1-auc:0.978976
# [177]	validation_0-auc:0.989509	validation_1-auc:0.978976
# [178]	validation_0-auc:0.989535	validation_1-auc:0.978985
# [179]	validation_0-auc:0.989561	validation_1-auc:0.979004
# [180]	validation_0-auc:0.989583	validation_1-auc:0.979014
# [181]	validation_0-auc:0.989592	validation_1-auc:0.979003
# [182]	validation_0-auc:0.989613	validation_1-auc:0.97901
# [183]	validation_0-auc:0.989637	validation_1-auc:0.979026
# [184]	validation_0-auc:0.98966	validation_1-auc:0.979029
# [185]	validation_0-auc:0.989684	validation_1-auc:0.979043
# [186]	validation_0-auc:0.989699	validation_1-auc:0.979052
# [187]	validation_0-auc:0.989711	validation_1-auc:0.979053
# [188]	validation_0-auc:0.989725	validation_1-auc:0.979048
# [189]	validation_0-auc:0.989753	validation_1-auc:0.979066
# [190]	validation_0-auc:0.989775	validation_1-auc:0.979071
# [191]	validation_0-auc:0.989796	validation_1-auc:0.979074
# [192]	validation_0-auc:0.989818	validation_1-auc:0.979076
# [193]	validation_0-auc:0.989836	validation_1-auc:0.979088
# [194]	validation_0-auc:0.989859	validation_1-auc:0.979096
# [195]	validation_0-auc:0.989881	validation_1-auc:0.979101
# [196]	validation_0-auc:0.989901	validation_1-auc:0.979113
# [197]	validation_0-auc:0.989917	validation_1-auc:0.979127
# [198]	validation_0-auc:0.989927	validation_1-auc:0.979128
# [199]	validation_0-auc:0.989939	validation_1-auc:0.979135
# [200]	validation_0-auc:0.989945	validation_1-auc:0.979132
# [201]	validation_0-auc:0.989966	validation_1-auc:0.97915
# [202]	validation_0-auc:0.989988	validation_1-auc:0.979161
# [203]	validation_0-auc:0.990009	validation_1-auc:0.979174
# [204]	validation_0-auc:0.99003	validation_1-auc:0.979182
# [205]	validation_0-auc:0.990057	validation_1-auc:0.979192
# [206]	validation_0-auc:0.990077	validation_1-auc:0.979196
# [207]	validation_0-auc:0.990087	validation_1-auc:0.979194
# [208]	validation_0-auc:0.990099	validation_1-auc:0.979199
# [209]	validation_0-auc:0.990116	validation_1-auc:0.979195
# [210]	validation_0-auc:0.990135	validation_1-auc:0.979199
# [211]	validation_0-auc:0.990145	validation_1-auc:0.979199
# [212]	validation_0-auc:0.990166	validation_1-auc:0.9792
# [213]	validation_0-auc:0.990176	validation_1-auc:0.979203
# [214]	validation_0-auc:0.990188	validation_1-auc:0.979204
# [215]	validation_0-auc:0.990203	validation_1-auc:0.979208
# [216]	validation_0-auc:0.990216	validation_1-auc:0.979209
# [217]	validation_0-auc:0.990225	validation_1-auc:0.979211
# [218]	validation_0-auc:0.990244	validation_1-auc:0.97922
# [219]	validation_0-auc:0.990257	validation_1-auc:0.97922
# [220]	validation_0-auc:0.990287	validation_1-auc:0.979222
# [221]	validation_0-auc:0.9903	validation_1-auc:0.97923
# [222]	validation_0-auc:0.990319	validation_1-auc:0.979234
# [223]	validation_0-auc:0.990328	validation_1-auc:0.97923
# [224]	validation_0-auc:0.990335	validation_1-auc:0.979231
# [225]	validation_0-auc:0.990348	validation_1-auc:0.979234
# [226]	validation_0-auc:0.990365	validation_1-auc:0.979234
# [227]	validation_0-auc:0.99037	validation_1-auc:0.979232
# [228]	validation_0-auc:0.990382	validation_1-auc:0.979233
# [229]	validation_0-auc:0.990401	validation_1-auc:0.979238
# [230]	validation_0-auc:0.990417	validation_1-auc:0.979231
# [231]	validation_0-auc:0.990429	validation_1-auc:0.979228
# [232]	validation_0-auc:0.990445	validation_1-auc:0.97923
# [233]	validation_0-auc:0.990458	validation_1-auc:0.979229
# [234]	validation_0-auc:0.990475	validation_1-auc:0.979235
# [235]	validation_0-auc:0.99049	validation_1-auc:0.979234
# [236]	validation_0-auc:0.990503	validation_1-auc:0.979229
# [237]	validation_0-auc:0.990519	validation_1-auc:0.979225
# [238]	validation_0-auc:0.990534	validation_1-auc:0.979221
# [239]	validation_0-auc:0.990551	validation_1-auc:0.979215
# [240]	validation_0-auc:0.990575	validation_1-auc:0.979219
# [241]	validation_0-auc:0.99059	validation_1-auc:0.979214
# [242]	validation_0-auc:0.990631	validation_1-auc:0.979225
# [243]	validation_0-auc:0.990641	validation_1-auc:0.979225
# [244]	validation_0-auc:0.990668	validation_1-auc:0.979235
# [245]	validation_0-auc:0.990675	validation_1-auc:0.979235
# [246]	validation_0-auc:0.990685	validation_1-auc:0.97924
# [247]	validation_0-auc:0.990697	validation_1-auc:0.979241
# [248]	validation_0-auc:0.990707	validation_1-auc:0.979244
# [249]	validation_0-auc:0.990754	validation_1-auc:0.97925
# [250]	validation_0-auc:0.990765	validation_1-auc:0.979252
# [251]	validation_0-auc:0.990774	validation_1-auc:0.979253
# [252]	validation_0-auc:0.990786	validation_1-auc:0.979251
# [253]	validation_0-auc:0.990802	validation_1-auc:0.979252
# [254]	validation_0-auc:0.990829	validation_1-auc:0.979259
# [255]	validation_0-auc:0.990842	validation_1-auc:0.979259
# [256]	validation_0-auc:0.990863	validation_1-auc:0.979257
# [257]	validation_0-auc:0.990876	validation_1-auc:0.979255
# [258]	validation_0-auc:0.990887	validation_1-auc:0.979256
# [259]	validation_0-auc:0.990894	validation_1-auc:0.979254
# [260]	validation_0-auc:0.990925	validation_1-auc:0.979262
# [261]	validation_0-auc:0.990936	validation_1-auc:0.979259
# [262]	validation_0-auc:0.99095	validation_1-auc:0.97926
# [263]	validation_0-auc:0.990962	validation_1-auc:0.97926
# [264]	validation_0-auc:0.991007	validation_1-auc:0.979272
# [265]	validation_0-auc:0.991029	validation_1-auc:0.979272
# [266]	validation_0-auc:0.991041	validation_1-auc:0.979274
# [267]	validation_0-auc:0.991057	validation_1-auc:0.979267
# [268]	validation_0-auc:0.991074	validation_1-auc:0.979271
# [269]	validation_0-auc:0.991087	validation_1-auc:0.979276
# [270]	validation_0-auc:0.9911	validation_1-auc:0.979277
# [271]	validation_0-auc:0.991119	validation_1-auc:0.97928
# [272]	validation_0-auc:0.991142	validation_1-auc:0.97928
# [273]	validation_0-auc:0.991151	validation_1-auc:0.979281
# [274]	validation_0-auc:0.991162	validation_1-auc:0.979283
# [275]	validation_0-auc:0.99121	validation_1-auc:0.979292
# [276]	validation_0-auc:0.991221	validation_1-auc:0.979297
# [277]	validation_0-auc:0.99124	validation_1-auc:0.979295
# [278]	validation_0-auc:0.991259	validation_1-auc:0.979293
# [279]	validation_0-auc:0.991288	validation_1-auc:0.979295
# [280]	validation_0-auc:0.991298	validation_1-auc:0.979292
# [281]	validation_0-auc:0.99131	validation_1-auc:0.979285
# [282]	validation_0-auc:0.991321	validation_1-auc:0.979286
# [283]	validation_0-auc:0.99133	validation_1-auc:0.979282
# [284]	validation_0-auc:0.991352	validation_1-auc:0.979289
# [285]	validation_0-auc:0.991362	validation_1-auc:0.979289
# [286]	validation_0-auc:0.991386	validation_1-auc:0.97929
# [287]	validation_0-auc:0.991396	validation_1-auc:0.979288
# [288]	validation_0-auc:0.991403	validation_1-auc:0.979289
# [289]	validation_0-auc:0.991412	validation_1-auc:0.979288
# [290]	validation_0-auc:0.991417	validation_1-auc:0.979291
# [291]	validation_0-auc:0.991432	validation_1-auc:0.979289
# [292]	validation_0-auc:0.991446	validation_1-auc:0.97929
# [293]	validation_0-auc:0.991457	validation_1-auc:0.979289
# [294]	validation_0-auc:0.991471	validation_1-auc:0.979289
# [295]	validation_0-auc:0.991488	validation_1-auc:0.979288
# [296]	validation_0-auc:0.991491	validation_1-auc:0.979285
# [297]	validation_0-auc:0.991504	validation_1-auc:0.979285
# [298]	validation_0-auc:0.991517	validation_1-auc:0.979281
# [299]	validation_0-auc:0.991531	validation_1-auc:0.979284
# [300]	validation_0-auc:0.991547	validation_1-auc:0.979283
# [301]	validation_0-auc:0.991555	validation_1-auc:0.979284
# [302]	validation_0-auc:0.99157	validation_1-auc:0.979285
# [303]	validation_0-auc:0.991579	validation_1-auc:0.979282
# [304]	validation_0-auc:0.99159	validation_1-auc:0.979284
# [305]	validation_0-auc:0.99161	validation_1-auc:0.979282
# [306]	validation_0-auc:0.991623	validation_1-auc:0.97928
# [307]	validation_0-auc:0.991636	validation_1-auc:0.979282
# [308]	validation_0-auc:0.991648	validation_1-auc:0.979283
# [309]	validation_0-auc:0.991661	validation_1-auc:0.979286
# [310]	validation_0-auc:0.991669	validation_1-auc:0.979284
# [311]	validation_0-auc:0.991693	validation_1-auc:0.979291
# [312]	validation_0-auc:0.991702	validation_1-auc:0.979293
# [313]	validation_0-auc:0.991737	validation_1-auc:0.979298
# [314]	validation_0-auc:0.991753	validation_1-auc:0.979298
# [315]	validation_0-auc:0.991767	validation_1-auc:0.979301
# [316]	validation_0-auc:0.991781	validation_1-auc:0.9793
# [317]	validation_0-auc:0.991803	validation_1-auc:0.9793
# [318]	validation_0-auc:0.991813	validation_1-auc:0.979299
# [319]	validation_0-auc:0.991827	validation_1-auc:0.979301
# [320]	validation_0-auc:0.991843	validation_1-auc:0.979304
# [321]	validation_0-auc:0.991856	validation_1-auc:0.979305
# [322]	validation_0-auc:0.99187	validation_1-auc:0.97931
# [323]	validation_0-auc:0.991885	validation_1-auc:0.979312
# [324]	validation_0-auc:0.991896	validation_1-auc:0.979313
# [325]	validation_0-auc:0.991917	validation_1-auc:0.979321
# [326]	validation_0-auc:0.991927	validation_1-auc:0.979322
# [327]	validation_0-auc:0.991935	validation_1-auc:0.979316
# [328]	validation_0-auc:0.991937	validation_1-auc:0.979317
# [329]	validation_0-auc:0.991951	validation_1-auc:0.979312
# [330]	validation_0-auc:0.99196	validation_1-auc:0.979313
# [331]	validation_0-auc:0.991974	validation_1-auc:0.979312
# [332]	validation_0-auc:0.991983	validation_1-auc:0.979311
# [333]	validation_0-auc:0.991994	validation_1-auc:0.97931
# [334]	validation_0-auc:0.992006	validation_1-auc:0.979311
# [335]	validation_0-auc:0.992029	validation_1-auc:0.979312
# [336]	validation_0-auc:0.992043	validation_1-auc:0.979312
# [337]	validation_0-auc:0.992047	validation_1-auc:0.97931
# [338]	validation_0-auc:0.992062	validation_1-auc:0.979307
# [339]	validation_0-auc:0.992066	validation_1-auc:0.979307
# [340]	validation_0-auc:0.99208	validation_1-auc:0.979308
# [341]	validation_0-auc:0.992096	validation_1-auc:0.979306
# [342]	validation_0-auc:0.992114	validation_1-auc:0.9793
# [343]	validation_0-auc:0.992129	validation_1-auc:0.979307
# [344]	validation_0-auc:0.992146	validation_1-auc:0.979302
# [345]	validation_0-auc:0.992172	validation_1-auc:0.979301
# [346]	validation_0-auc:0.992191	validation_1-auc:0.979301
# [347]	validation_0-auc:0.992202	validation_1-auc:0.979297
# [348]	validation_0-auc:0.992207	validation_1-auc:0.979297
# [349]	validation_0-auc:0.992215	validation_1-auc:0.979295
# [350]	validation_0-auc:0.992226	validation_1-auc:0.979295
# [351]	validation_0-auc:0.992231	validation_1-auc:0.979294
# [352]	validation_0-auc:0.992244	validation_1-auc:0.979289
# [353]	validation_0-auc:0.992254	validation_1-auc:0.979288
# [354]	validation_0-auc:0.992267	validation_1-auc:0.97929
# [355]	validation_0-auc:0.992274	validation_1-auc:0.979292
# [356]	validation_0-auc:0.992286	validation_1-auc:0.979291
# [357]	validation_0-auc:0.992292	validation_1-auc:0.979293
# [358]	validation_0-auc:0.992307	validation_1-auc:0.979289
# [359]	validation_0-auc:0.992329	validation_1-auc:0.979292
# [360]	validation_0-auc:0.992337	validation_1-auc:0.979291
# [361]	validation_0-auc:0.992345	validation_1-auc:0.979289
# [362]	validation_0-auc:0.992358	validation_1-auc:0.979286
# [363]	validation_0-auc:0.992371	validation_1-auc:0.979283
# [364]	validation_0-auc:0.992383	validation_1-auc:0.979283
# [365]	validation_0-auc:0.992401	validation_1-auc:0.979281
# [366]	validation_0-auc:0.992418	validation_1-auc:0.979279
# [367]	validation_0-auc:0.99243	validation_1-auc:0.979282
# [368]	validation_0-auc:0.992451	validation_1-auc:0.979279
# [369]	validation_0-auc:0.99246	validation_1-auc:0.979276
# [370]	validation_0-auc:0.992472	validation_1-auc:0.979276
# [371]	validation_0-auc:0.992485	validation_1-auc:0.979276
# [372]	validation_0-auc:0.992494	validation_1-auc:0.979273
# [373]	validation_0-auc:0.992501	validation_1-auc:0.979272
# [374]	validation_0-auc:0.992514	validation_1-auc:0.979273
# [375]	validation_0-auc:0.992532	validation_1-auc:0.97927
# [376]	validation_0-auc:0.992549	validation_1-auc:0.979269
# [377]	validation_0-auc:0.992555	validation_1-auc:0.979269
# [378]	validation_0-auc:0.992568	validation_1-auc:0.97927
# [379]	validation_0-auc:0.99258	validation_1-auc:0.97927
# [380]	validation_0-auc:0.992607	validation_1-auc:0.979265
# [381]	validation_0-auc:0.992614	validation_1-auc:0.979267
# [382]	validation_0-auc:0.992631	validation_1-auc:0.979268
# [383]	validation_0-auc:0.992658	validation_1-auc:0.97927
# [384]	validation_0-auc:0.992669	validation_1-auc:0.979269
# [385]	validation_0-auc:0.992677	validation_1-auc:0.979269
# [386]	validation_0-auc:0.992686	validation_1-auc:0.979268
# [387]	validation_0-auc:0.992701	validation_1-auc:0.979262
# [388]	validation_0-auc:0.992716	validation_1-auc:0.979268
# [389]	validation_0-auc:0.992728	validation_1-auc:0.979267
# [390]	validation_0-auc:0.99274	validation_1-auc:0.979268
# [391]	validation_0-auc:0.992751	validation_1-auc:0.979266
# [392]	validation_0-auc:0.992756	validation_1-auc:0.979268
# [393]	validation_0-auc:0.992764	validation_1-auc:0.979266
# [394]	validation_0-auc:0.992767	validation_1-auc:0.979262
# [395]	validation_0-auc:0.992781	validation_1-auc:0.97926
# [396]	validation_0-auc:0.992797	validation_1-auc:0.979257
# [397]	validation_0-auc:0.992806	validation_1-auc:0.979256
# [398]	validation_0-auc:0.992815	validation_1-auc:0.979252
# [399]	validation_0-auc:0.992818	validation_1-auc:0.979251
# [400]	validation_0-auc:0.992827	validation_1-auc:0.979248
# [401]	validation_0-auc:0.992838	validation_1-auc:0.97925
# [402]	validation_0-auc:0.992852	validation_1-auc:0.979248
# [403]	validation_0-auc:0.992859	validation_1-auc:0.979249
# [404]	validation_0-auc:0.992882	validation_1-auc:0.979245
# [405]	validation_0-auc:0.992896	validation_1-auc:0.979242
# [406]	validation_0-auc:0.992908	validation_1-auc:0.979243
# [407]	validation_0-auc:0.992939	validation_1-auc:0.979244
# [408]	validation_0-auc:0.992945	validation_1-auc:0.979245
# [409]	validation_0-auc:0.992951	validation_1-auc:0.979242
# [410]	validation_0-auc:0.992959	validation_1-auc:0.979244
# [411]	validation_0-auc:0.992979	validation_1-auc:0.979245
# [412]	validation_0-auc:0.992992	validation_1-auc:0.979242
# [413]	validation_0-auc:0.992996	validation_1-auc:0.979239
# [414]	validation_0-auc:0.993008	validation_1-auc:0.979233
# [415]	validation_0-auc:0.993017	validation_1-auc:0.97923
# [416]	validation_0-auc:0.993032	validation_1-auc:0.979232
# [417]	validation_0-auc:0.993044	validation_1-auc:0.979232
# [418]	validation_0-auc:0.993056	validation_1-auc:0.979233
# [419]	validation_0-auc:0.993063	validation_1-auc:0.97923
# [420]	validation_0-auc:0.993077	validation_1-auc:0.979233
# [421]	validation_0-auc:0.993098	validation_1-auc:0.979231
# [422]	validation_0-auc:0.993105	validation_1-auc:0.979232
# [423]	validation_0-auc:0.993111	validation_1-auc:0.979235
# [424]	validation_0-auc:0.993122	validation_1-auc:0.979241
# [425]	validation_0-auc:0.993138	validation_1-auc:0.979239
# [426]	validation_0-auc:0.993146	validation_1-auc:0.97924
# Stopping. Best iteration:
# [326]	validation_0-auc:0.991927	validation_1-auc:0.979322
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.03, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=20000,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=420, silent=True, subsample=0.8)

# %%
sorted(zip(train_x.columns.values, models.feature_importances_), key=lambda x: x[1], reverse=True)
# Out:
# [('y_entry', 0.09221833),
#  ('hour_15', 0.048976768),
#  ('x_entry', 0.03863641),
#  ('duration', 0.028115653),
#  ('hour_14', 0.0093169585),
#  ('minute_13', 0.008715211),
#  ('minute_6', 0.008353286),
#  ('eminute_54', 0.008014485),
#  ('eminute_11', 0.008009848),
#  ('minute_35', 0.00793254),
#  ('minute_37', 0.007853216),
#  ('eminute_48', 0.007819084),
#  ('eminute_55', 0.007811645),
#  ('minute_15', 0.0077561117),
#  ('eminute_25', 0.007724879),
#  ('vmean', 0.0074633094),
#  ('eminute_0', 0.0074485424),
#  ('eminute_26', 0.0074340864),
#  ('minute_53', 0.007339699),
#  ('minute_49', 0.007315526),
#  ('eminute_53', 0.0072835307),
#  ('eminute_23', 0.0072233994),
#  ('minute_12', 0.007126608),
#  ('eminute_42', 0.007089619),
#  ('minute_59', 0.0070661516),
#  ('eminute_16', 0.007033363),
#  ('eminute_29', 0.006918468),
#  ('eminute_21', 0.006905095),
#  ('eminute_6', 0.006903897),
#  ('minute_9', 0.0068666134),
#  ('minute_46', 0.0068558753),
#  ('eminute_18', 0.006852153),
#  ('minute_24', 0.0068235043),
#  ('minute_31', 0.0068089776),
#  ('minute_40', 0.006798282),
#  ('minute_41', 0.006780984),
#  ('eminute_44', 0.0067584286),
#  ('eminute_38', 0.0067158295),
#  ('minute_17', 0.0067103007),
#  ('minute_3', 0.006708964),
#  ('minute_33', 0.0066959304),
#  ('eminute_9', 0.0066447267),
#  ('eminute_2', 0.0066059628),
#  ('eminute_40', 0.006605606),
#  ('minute_55', 0.006584478),
#  ('eminute_31', 0.006583725),
#  ('eminute_4', 0.0065826178),
#  ('eminute_41', 0.0065794857),
#  ('eminute_32', 0.0065711),
#  ('minute_8', 0.0065593733),
#  ('minute_52', 0.006525527),
#  ('eminute_43', 0.0064962287),
#  ('minute_18', 0.0064809006),
#  ('minute_42', 0.006471749),
#  ('eminute_45', 0.006469803),
#  ('minute_32', 0.006451695),
#  ('eminute_13', 0.0064061596),
#  ('minute_29', 0.0064044106),
#  ('minute_14', 0.0064029708),
#  ('minute_54', 0.006366327),
#  ('eminute_35', 0.006335048),
#  ('eminute_7', 0.006331049),
#  ('eminute_47', 0.006311658),
#  ('minute_43', 0.0063100294),
#  ('minute_27', 0.006305045),
#  ('minute_36', 0.006304214),
#  ('eminute_14', 0.006284734),
#  ('minute_11', 0.006275741),
#  ('minute_19', 0.0062274477),
#  ('minute_7', 0.0062199207),
#  ('minute_16', 0.006217926),
#  ('eminute_27', 0.0062072384),
#  ('eminute_28', 0.006203687),
#  ('eminute_15', 0.0062008384),
#  ('eminute_5', 0.006174704),
#  ('vmax', 0.006168028),
#  ('eminute_3', 0.006161539),
#  ('eminute_24', 0.006138227),
#  ('eminute_52', 0.0061261673),
#  ('minute_44', 0.006114288),
#  ('eminute_30', 0.006113311),
#  ('eminute_58', 0.006075473),
#  ('minute_22', 0.0060396288),
#  ('minute_47', 0.0060379435),
#  ('eminute_17', 0.00603363),
#  ('eminute_34', 0.0060204053),
#  ('eminute_1', 0.0060101273),
#  ('minute_58', 0.0060022655),
#  ('minute_26', 0.0059758797),
#  ('vmin', 0.005933763),
#  ('eminute_46', 0.0059235757),
#  ('eminute_39', 0.005909632),
#  ('minute_0', 0.005889538),
#  ('minute_38', 0.005884612),
#  ('minute_25', 0.005859282),
#  ('eminute_56', 0.005858062),
#  ('minute_28', 0.005818786),
#  ('minute_23', 0.005806871),
#  ('minute_5', 0.005803163),
#  ('eminute_33', 0.005780092),
#  ('eminute_10', 0.00576823),
#  ('eminute_12', 0.005755997),
#  ('minute_1', 0.005690435),
#  ('eminute_36', 0.0056716795),
#  ('minute_10', 0.0056356085),
#  ('eminute_19', 0.0055893403),
#  ('minute_39', 0.00557862),
#  ('minute_48', 0.0055731763),
#  ('eminute_50', 0.005552388),
#  ('minute_56', 0.005540343),
#  ('minute_30', 0.0055013495),
#  ('eminute_20', 0.0054837572),
#  ('eminute_37', 0.005478503),
#  ('eminute_22', 0.005454304),
#  ('minute_51', 0.00541355),
#  ('eminute_8', 0.005394726),
#  ('minute_57', 0.005331454),
#  ('minute_50', 0.005322707),
#  ('minute_4', 0.0052856645),
#  ('minute_20', 0.005272924),
#  ('eminute_49', 0.0052668774),
#  ('minute_2', 0.00521265),
#  ('minute_21', 0.0051274383),
#  ('eminute_59', 0.005065268),
#  ('eminute_51', 0.0049536666),
#  ('minute_45', 0.0048994184),
#  ('eminute_57', 0.0043371757),
#  ('hour_13', 0.0039643547),
#  ('minute_34', 0.00368793),
#  ('hour_12', 0.00082248746),
#  ('hour_10', 0.0),
#  ('hour_11', 0.0),
#  ('hour_16', 0.0),
#  ('ehour_15', 0.0),
#  ('ehour_16', 0.0)]

# %%
pred_y = models.predict(test_x)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
(pred_y==test_y).sum()/test_y.count()
# Out:
# 0.9357028307164436

# %%
models2 = xgb.XGBClassifier(max_depth=10, learning_rate=0.03, n_estimators=326, n_jobs=-1,
                           subsample=0.8, colsample_bytree=0.8, seed=420)

# %%
models2.fit(X, Y, eval_metric='auc', eval_set=[(X, Y)])
# Out:
# [0]	validation_0-auc:0.979616
# [1]	validation_0-auc:0.980679
# [2]	validation_0-auc:0.981397
# [3]	validation_0-auc:0.981705
# [4]	validation_0-auc:0.981989
# [5]	validation_0-auc:0.980222
# [6]	validation_0-auc:0.980309
# [7]	validation_0-auc:0.980898
# [8]	validation_0-auc:0.981305
# [9]	validation_0-auc:0.981443
# [10]	validation_0-auc:0.981857
# [11]	validation_0-auc:0.982085
# [12]	validation_0-auc:0.982331
# [13]	validation_0-auc:0.982668
# [14]	validation_0-auc:0.982848
# [15]	validation_0-auc:0.982996
# [16]	validation_0-auc:0.983065
# [17]	validation_0-auc:0.983021
# [18]	validation_0-auc:0.9832
# [19]	validation_0-auc:0.983333
# [20]	validation_0-auc:0.983448
# [21]	validation_0-auc:0.983561
# [22]	validation_0-auc:0.983565
# [23]	validation_0-auc:0.983673
# [24]	validation_0-auc:0.983588
# [25]	validation_0-auc:0.983441
# [26]	validation_0-auc:0.983428
# [27]	validation_0-auc:0.983558
# [28]	validation_0-auc:0.983371
# [29]	validation_0-auc:0.983582
# [30]	validation_0-auc:0.983408
# [31]	validation_0-auc:0.983592
# [32]	validation_0-auc:0.983663
# [33]	validation_0-auc:0.983551
# [34]	validation_0-auc:0.983704
# [35]	validation_0-auc:0.983882
# [36]	validation_0-auc:0.983967
# [37]	validation_0-auc:0.984006
# [38]	validation_0-auc:0.984019
# [39]	validation_0-auc:0.984148
# [40]	validation_0-auc:0.9843
# [41]	validation_0-auc:0.984313
# [42]	validation_0-auc:0.984348
# [43]	validation_0-auc:0.984463
# [44]	validation_0-auc:0.984578
# [45]	validation_0-auc:0.984669
# [46]	validation_0-auc:0.984673
# [47]	validation_0-auc:0.984766
# [48]	validation_0-auc:0.984876
# [49]	validation_0-auc:0.984924
# [50]	validation_0-auc:0.985011
# [51]	validation_0-auc:0.985085
# [52]	validation_0-auc:0.985177
# [53]	validation_0-auc:0.985174
# [54]	validation_0-auc:0.985177
# [55]	validation_0-auc:0.985252
# [56]	validation_0-auc:0.985258
# [57]	validation_0-auc:0.98527
# [58]	validation_0-auc:0.985358
# [59]	validation_0-auc:0.985364
# [60]	validation_0-auc:0.985436
# [61]	validation_0-auc:0.985505
# [62]	validation_0-auc:0.98557
# [63]	validation_0-auc:0.985629
# [64]	validation_0-auc:0.98564
# [65]	validation_0-auc:0.98572
# [66]	validation_0-auc:0.985768
# [67]	validation_0-auc:0.985777
# [68]	validation_0-auc:0.985809
# [69]	validation_0-auc:0.985818
# [70]	validation_0-auc:0.985883
# [71]	validation_0-auc:0.985936
# [72]	validation_0-auc:0.985965
# [73]	validation_0-auc:0.98599
# [74]	validation_0-auc:0.986045
# [75]	validation_0-auc:0.986104
# [76]	validation_0-auc:0.986123
# [77]	validation_0-auc:0.986127
# [78]	validation_0-auc:0.986189
# [79]	validation_0-auc:0.986246
# [80]	validation_0-auc:0.986307
# [81]	validation_0-auc:0.986354
# [82]	validation_0-auc:0.98642
# [83]	validation_0-auc:0.98645
# [84]	validation_0-auc:0.986473
# [85]	validation_0-auc:0.986518
# [86]	validation_0-auc:0.98657
# [87]	validation_0-auc:0.986611
# [88]	validation_0-auc:0.986618
# [89]	validation_0-auc:0.986619
# [90]	validation_0-auc:0.986628
# [91]	validation_0-auc:0.986662
# [92]	validation_0-auc:0.98668
# [93]	validation_0-auc:0.986699
# [94]	validation_0-auc:0.986749
# [95]	validation_0-auc:0.986753
# [96]	validation_0-auc:0.986764
# [97]	validation_0-auc:0.986816
# [98]	validation_0-auc:0.986857
# [99]	validation_0-auc:0.986897
# [100]	validation_0-auc:0.986936
# [101]	validation_0-auc:0.986969
# [102]	validation_0-auc:0.987016
# [103]	validation_0-auc:0.987037
# [104]	validation_0-auc:0.987084
# [105]	validation_0-auc:0.987117
# [106]	validation_0-auc:0.987152
# [107]	validation_0-auc:0.987188
# [108]	validation_0-auc:0.987222
# [109]	validation_0-auc:0.98726
# [110]	validation_0-auc:0.987269
# [111]	validation_0-auc:0.987309
# [112]	validation_0-auc:0.987348
# [113]	validation_0-auc:0.987362
# [114]	validation_0-auc:0.98739
# [115]	validation_0-auc:0.987425
# [116]	validation_0-auc:0.987439
# [117]	validation_0-auc:0.987474
# [118]	validation_0-auc:0.987479
# [119]	validation_0-auc:0.987477
# [120]	validation_0-auc:0.987486
# [121]	validation_0-auc:0.987523
# [122]	validation_0-auc:0.987562
# [123]	validation_0-auc:0.987578
# [124]	validation_0-auc:0.987617
# [125]	validation_0-auc:0.987655
# [126]	validation_0-auc:0.987686
# [127]	validation_0-auc:0.987705
# [128]	validation_0-auc:0.987728
# [129]	validation_0-auc:0.987766
# [130]	validation_0-auc:0.987806
# [131]	validation_0-auc:0.987814
# [132]	validation_0-auc:0.98783
# [133]	validation_0-auc:0.987852
# [134]	validation_0-auc:0.987876
# [135]	validation_0-auc:0.987886
# [136]	validation_0-auc:0.987915
# [137]	validation_0-auc:0.987946
# [138]	validation_0-auc:0.987963
# [139]	validation_0-auc:0.987998
# [140]	validation_0-auc:0.988018
# [141]	validation_0-auc:0.98805
# [142]	validation_0-auc:0.988079
# [143]	validation_0-auc:0.988098
# [144]	validation_0-auc:0.988121
# [145]	validation_0-auc:0.988142
# [146]	validation_0-auc:0.988166
# [147]	validation_0-auc:0.988189
# [148]	validation_0-auc:0.988212
# [149]	validation_0-auc:0.988242
# [150]	validation_0-auc:0.988263
# [151]	validation_0-auc:0.98828
# [152]	validation_0-auc:0.988307
# [153]	validation_0-auc:0.988337
# [154]	validation_0-auc:0.98836
# [155]	validation_0-auc:0.988384
# [156]	validation_0-auc:0.9884
# [157]	validation_0-auc:0.988425
# [158]	validation_0-auc:0.988454
# [159]	validation_0-auc:0.988476
# [160]	validation_0-auc:0.988492
# [161]	validation_0-auc:0.988505
# [162]	validation_0-auc:0.98853
# [163]	validation_0-auc:0.98856
# [164]	validation_0-auc:0.988575
# [165]	validation_0-auc:0.988588
# [166]	validation_0-auc:0.988605
# [167]	validation_0-auc:0.988611
# [168]	validation_0-auc:0.988633
# [169]	validation_0-auc:0.988657
# [170]	validation_0-auc:0.988673
# [171]	validation_0-auc:0.988688
# [172]	validation_0-auc:0.988706
# [173]	validation_0-auc:0.988725
# [174]	validation_0-auc:0.988741
# [175]	validation_0-auc:0.988762
# [176]	validation_0-auc:0.988787
# [177]	validation_0-auc:0.988809
# [178]	validation_0-auc:0.988825
# [179]	validation_0-auc:0.98884
# [180]	validation_0-auc:0.98885
# [181]	validation_0-auc:0.988871
# [182]	validation_0-auc:0.988896
# [183]	validation_0-auc:0.988905
# [184]	validation_0-auc:0.988923
# [185]	validation_0-auc:0.98893
# [186]	validation_0-auc:0.988951
# [187]	validation_0-auc:0.988965
# [188]	validation_0-auc:0.988973
# [189]	validation_0-auc:0.988985
# [190]	validation_0-auc:0.989003
# [191]	validation_0-auc:0.989023
# [192]	validation_0-auc:0.989038
# [193]	validation_0-auc:0.989051
# [194]	validation_0-auc:0.989067
# [195]	validation_0-auc:0.989078
# [196]	validation_0-auc:0.98909
# [197]	validation_0-auc:0.989106
# [198]	validation_0-auc:0.989119
# [199]	validation_0-auc:0.98913
# [200]	validation_0-auc:0.989159
# [201]	validation_0-auc:0.989172
# [202]	validation_0-auc:0.989185
# [203]	validation_0-auc:0.989197
# [204]	validation_0-auc:0.989203
# [205]	validation_0-auc:0.989223
# [206]	validation_0-auc:0.989238
# [207]	validation_0-auc:0.989255
# [208]	validation_0-auc:0.989273
# [209]	validation_0-auc:0.9893
# [210]	validation_0-auc:0.989306
# [211]	validation_0-auc:0.98932
# [212]	validation_0-auc:0.989338
# [213]	validation_0-auc:0.989357
# [214]	validation_0-auc:0.989365
# [215]	validation_0-auc:0.989373
# [216]	validation_0-auc:0.989381
# [217]	validation_0-auc:0.989391
# [218]	validation_0-auc:0.989402
# [219]	validation_0-auc:0.989416
# [220]	validation_0-auc:0.98943
# [221]	validation_0-auc:0.989442
# [222]	validation_0-auc:0.989451
# [223]	validation_0-auc:0.989469
# [224]	validation_0-auc:0.989484
# [225]	validation_0-auc:0.989516
# [226]	validation_0-auc:0.989526
# [227]	validation_0-auc:0.989568
# [228]	validation_0-auc:0.989584
# [229]	validation_0-auc:0.989601
# [230]	validation_0-auc:0.989609
# [231]	validation_0-auc:0.989621
# [232]	validation_0-auc:0.989631
# [233]	validation_0-auc:0.989648
# [234]	validation_0-auc:0.989662
# [235]	validation_0-auc:0.989676
# [236]	validation_0-auc:0.989688
# [237]	validation_0-auc:0.989697
# [238]	validation_0-auc:0.989706
# [239]	validation_0-auc:0.989719
# [240]	validation_0-auc:0.989749
# [241]	validation_0-auc:0.989767
# [242]	validation_0-auc:0.989785
# [243]	validation_0-auc:0.989804
# [244]	validation_0-auc:0.989822
# [245]	validation_0-auc:0.989836
# [246]	validation_0-auc:0.989854
# [247]	validation_0-auc:0.989867
# [248]	validation_0-auc:0.989876
# [249]	validation_0-auc:0.989884
# [250]	validation_0-auc:0.989892
# [251]	validation_0-auc:0.989907
# [252]	validation_0-auc:0.98994
# [253]	validation_0-auc:0.989961
# [254]	validation_0-auc:0.989972
# [255]	validation_0-auc:0.989982
# [256]	validation_0-auc:0.989989
# [257]	validation_0-auc:0.989997
# [258]	validation_0-auc:0.990006
# [259]	validation_0-auc:0.990019
# [260]	validation_0-auc:0.990027
# [261]	validation_0-auc:0.990048
# [262]	validation_0-auc:0.990063
# [263]	validation_0-auc:0.990076
# [264]	validation_0-auc:0.990086
# [265]	validation_0-auc:0.990101
# [266]	validation_0-auc:0.990106
# [267]	validation_0-auc:0.99012
# [268]	validation_0-auc:0.990136
# [269]	validation_0-auc:0.990168
# [270]	validation_0-auc:0.990182
# [271]	validation_0-auc:0.990197
# [272]	validation_0-auc:0.990205
# [273]	validation_0-auc:0.990216
# [274]	validation_0-auc:0.990227
# [275]	validation_0-auc:0.990241
# [276]	validation_0-auc:0.99025
# [277]	validation_0-auc:0.990267
# [278]	validation_0-auc:0.990277
# [279]	validation_0-auc:0.990288
# [280]	validation_0-auc:0.990305
# [281]	validation_0-auc:0.990312
# [282]	validation_0-auc:0.990323
# [283]	validation_0-auc:0.990336
# [284]	validation_0-auc:0.990353
# [285]	validation_0-auc:0.990361
# [286]	validation_0-auc:0.990385
# [287]	validation_0-auc:0.990403
# [288]	validation_0-auc:0.990409
# [289]	validation_0-auc:0.990415
# [290]	validation_0-auc:0.990425
# [291]	validation_0-auc:0.990436
# [292]	validation_0-auc:0.990445
# [293]	validation_0-auc:0.990453
# [294]	validation_0-auc:0.990463
# [295]	validation_0-auc:0.990476
# [296]	validation_0-auc:0.99048
# [297]	validation_0-auc:0.990511
# [298]	validation_0-auc:0.990521
# [299]	validation_0-auc:0.99053
# [300]	validation_0-auc:0.990539
# [301]	validation_0-auc:0.990545
# [302]	validation_0-auc:0.990559
# [303]	validation_0-auc:0.990569
# [304]	validation_0-auc:0.990589
# [305]	validation_0-auc:0.9906
# [306]	validation_0-auc:0.990612
# [307]	validation_0-auc:0.990622
# [308]	validation_0-auc:0.990631
# [309]	validation_0-auc:0.990639
# [310]	validation_0-auc:0.990649
# [311]	validation_0-auc:0.99067
# [312]	validation_0-auc:0.990682
# [313]	validation_0-auc:0.9907
# [314]	validation_0-auc:0.990713
# [315]	validation_0-auc:0.990725
# [316]	validation_0-auc:0.990747
# [317]	validation_0-auc:0.990754
# [318]	validation_0-auc:0.990768
# [319]	validation_0-auc:0.990777
# [320]	validation_0-auc:0.990791
# [321]	validation_0-auc:0.990798
# [322]	validation_0-auc:0.990807
# [323]	validation_0-auc:0.990817
# [324]	validation_0-auc:0.990832
# [325]	validation_0-auc:0.99084
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.03, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=326,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=420, silent=True, subsample=0.8)

# %% [markdown]
# # Make Prediction

# %%
test = pd.read_csv("data_test.csv")

# %%
test['time_entry'] = pd.to_datetime(test['time_entry'], format='%H:%M:%S')
test['time_exit']  = pd.to_datetime(test['time_exit'], format='%H:%M:%S')

# %%
test['duration'] = (test['time_exit'] - test['time_entry']).dt.total_seconds().astype(int)

# %%
test2 = test[test['time_exit'].dt.hour.between(15,16)]

# %%
test2.count()
# Out:
# Unnamed: 0       33515
# hash             33515
# trajectory_id    33515
# time_entry       33515
# time_exit        33515
# vmax                 0
# vmin                 0
# vmean                0
# x_entry          33515
# y_entry          33515
# x_exit               0
# y_exit               0
# duration         33515
# dtype: int64

# %%
devices = test.groupby('hash')
tname   = []
tlength = []
for name, group in devices:
    tname.append(name)
    tlength.append(group.shape[0])
tname   = pd.Series(tname)
tlength = pd.Series(tlength)

# %%
thour = entryHEnc.transform(test2['time_entry'].dt.hour.values.reshape(-1,1))
test2 = pd.concat([test2, pd.DataFrame(thour, columns=['hour_'+str(entryHEnc.active_features_[n]) for n in range(thour.shape[1])], 
                                      index=test2.index)], axis=1)

tminute = entryMEnc.transform(test2['time_entry'].dt.minute.values.reshape(-1,1))
test2 = pd.concat([test2, pd.DataFrame(tminute, columns=['minute_'+str(entryMEnc.active_features_[n]) for n in range(minute.shape[1])], 
                                      index=test2.index)], axis=1)

# %%
tehour = exitHEnc.transform(test2['time_exit'].dt.hour.values.reshape(-1,1))
test2 = pd.concat([test2, pd.DataFrame(tehour, columns=['ehour_'+str(exitHEnc.active_features_[n]) for n in range(tehour.shape[1])], 
                                      index=test2.index)], axis=1)

teminute = exitMEnc.transform(test2['time_exit'].dt.minute.values.reshape(-1,1))
test2 = pd.concat([test2, pd.DataFrame(teminute, columns=['eminute_'+str(exitMEnc.active_features_[n]) for n in range(teminute.shape[1])], 
                                      index=test2.index)], axis=1)

# %%
tX = test2.drop(['Unnamed: 0', 'hash', 'trajectory_id', 'time_entry', 'time_exit', 'x_exit', 'y_exit'], axis=1)

# %%
pred_y = models2.predict(tX)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print(pred_y.sum(), pred_y.shape)
# Out:
# 8199 (33515,)

# %%
output = pd.DataFrame({'id': test2['trajectory_id'], 'target': pred_y.astype(int)})
output.to_csv('submission3.csv', index=False, columns=['id', 'target'])
