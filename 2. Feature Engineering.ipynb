# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
from matplotlib.path import Path
import matplotlib.patches as patches
import seaborn as sns
from tqdm import tqdm
# %matplotlib inline

# %% [markdown]
# # 1. Preprocess

# %%
data = pd.read_csv("data/raw/data_train.csv")

# %%
data['time_entry'] = pd.to_datetime(data['time_entry'], format='%H:%M:%S')
data['time_exit']  = pd.to_datetime(data['time_exit'], format='%H:%M:%S')

# %%
data[:5]
# Out:
#    Unnamed: 0                                hash  \
# 0           0  0000a8602cf2def930488dee7cdad104_1
# 1           1  0000a8602cf2def930488dee7cdad104_1
# 2           2  0000a8602cf2def930488dee7cdad104_1
# 3           3  0000a8602cf2def930488dee7cdad104_1
# 4           4  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id          time_entry  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0 1900-01-01 07:04:31
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1 1900-01-01 07:20:34
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2 1900-01-01 07:53:32
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3 1900-01-01 08:17:50
# 4  traj_0000a8602cf2def930488dee7cdad104_1_4 1900-01-01 14:38:09
#
#             time_exit  vmax  vmin  vmean       x_entry       y_entry  \
# 0 1900-01-01 07:08:32   NaN   NaN    NaN  3.751014e+06 -1.909398e+07
# 1 1900-01-01 07:25:42   NaN   NaN    NaN  3.743937e+06 -1.932247e+07
# 2 1900-01-01 08:03:25   NaN   NaN    NaN  3.744868e+06 -1.929356e+07
# 3 1900-01-01 08:37:23   NaN   NaN    NaN  3.744880e+06 -1.929229e+07
# 4 1900-01-01 14:38:09   NaN   NaN    NaN  3.744909e+06 -1.928558e+07
#
#          x_exit        y_exit
# 0  3.750326e+06 -1.913634e+07
# 1  3.744975e+06 -1.931966e+07
# 2  3.744816e+06 -1.929284e+07
# 3  3.744809e+06 -1.929049e+07
# 4  3.744909e+06 -1.928558e+07

# %% [markdown]
# ## 1.2 Time Feature

# %%
data['duration'] = (data['time_exit'] - data['time_entry']).dt.total_seconds().astype(int)

# %%
data['entry_hour'] = data['time_entry'].dt.hour
data['entry_minute'] = data['time_entry'].dt.minute
data['entry_second'] = data['time_entry'].dt.second
data['exit_hour'] = data['time_exit'].dt.hour
data['exit_minute'] = data['time_exit'].dt.minute
data['exit_second'] = data['time_exit'].dt.second

# %%
len(data[:5].columns)
# Out:
# 19

# %%
data[:5].columns
# Out:
# Index(['Unnamed: 0', 'hash', 'trajectory_id', 'time_entry', 'time_exit',
#        'vmax', 'vmin', 'vmean', 'x_entry', 'y_entry', 'x_exit', 'y_exit',
#        'duration', 'entry_hour', 'entry_minute', 'entry_second', 'exit_hour',
#        'exit_minute', 'exit_second'],
#       dtype='object')

# %%
data[:5]
# Out:
#    Unnamed: 0                                hash  \
# 0           0  0000a8602cf2def930488dee7cdad104_1
# 1           1  0000a8602cf2def930488dee7cdad104_1
# 2           2  0000a8602cf2def930488dee7cdad104_1
# 3           3  0000a8602cf2def930488dee7cdad104_1
# 4           4  0000a8602cf2def930488dee7cdad104_1
#
#                                trajectory_id          time_entry  \
# 0  traj_0000a8602cf2def930488dee7cdad104_1_0 1900-01-01 07:04:31
# 1  traj_0000a8602cf2def930488dee7cdad104_1_1 1900-01-01 07:20:34
# 2  traj_0000a8602cf2def930488dee7cdad104_1_2 1900-01-01 07:53:32
# 3  traj_0000a8602cf2def930488dee7cdad104_1_3 1900-01-01 08:17:50
# 4  traj_0000a8602cf2def930488dee7cdad104_1_4 1900-01-01 14:38:09
#
#             time_exit  vmax  vmin  vmean       x_entry       y_entry  \
# 0 1900-01-01 07:08:32   NaN   NaN    NaN  3.751014e+06 -1.909398e+07
# 1 1900-01-01 07:25:42   NaN   NaN    NaN  3.743937e+06 -1.932247e+07
# 2 1900-01-01 08:03:25   NaN   NaN    NaN  3.744868e+06 -1.929356e+07
# 3 1900-01-01 08:37:23   NaN   NaN    NaN  3.744880e+06 -1.929229e+07
# 4 1900-01-01 14:38:09   NaN   NaN    NaN  3.744909e+06 -1.928558e+07
#
#          x_exit        y_exit  duration  entry_hour  entry_minute  \
# 0  3.750326e+06 -1.913634e+07       241           7             4
# 1  3.744975e+06 -1.931966e+07       308           7            20
# 2  3.744816e+06 -1.929284e+07       593           7            53
# 3  3.744809e+06 -1.929049e+07      1173           8            17
# 4  3.744909e+06 -1.928558e+07         0          14            38
#
#    entry_second  exit_hour  exit_minute  exit_second
# 0            31          7            8           32
# 1            34          7           25           42
# 2            32          8            3           25
# 3            50          8           37           23
# 4             9         14           38            9

# %% [markdown]
# ## 1.3 Concat Time Series

# %% [markdown]
# concatenate trajectories for each device into a row

# %%
groups = data.groupby("hash")

# %%
dependence = []
pbar = tqdm(total=len(groups))
for name, g in groups:
    pbar.update(1)
    available = [g.iloc[i] for i in range(len(g))]
    nanpaddin = [pd.Series([np.nan]*(20*len(data[:5].columns)-sum([len(x) for x in available])))]
    dependence.append(pd.concat(nanpaddin+available, axis=0, ignore_index=True))    
pbar.close()
# Out:
# 100%|██████████| 134063/134063 [04:34<00:00, 488.87it/s]

# %%
data2 = pd.concat(dependence, axis=1).T

# %%
data2.columns = [x + "_" + str(y) for y in range(20) for x in data.columns]

# %%
data2[:5]
# Out:
#   Unnamed: 0_0 hash_0 trajectory_id_0 time_entry_0 time_exit_0 vmax_0 vmin_0  \
# 0          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 1          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 2          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 3          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 4          NaN    NaN             NaN          NaN         NaN    NaN    NaN
#
#   vmean_0 x_entry_0 y_entry_0      ...         y_entry_19    x_exit_19  \
# 0     NaN       NaN       NaN      ...       -1.92818e+07  3.74479e+06
# 1     NaN       NaN       NaN      ...       -1.92661e+07  3.74961e+06
# 2     NaN       NaN       NaN      ...       -1.93759e+07  3.76969e+06
# 3     NaN       NaN       NaN      ...        -1.9178e+07  3.76787e+06
# 4     NaN       NaN       NaN      ...        -1.9227e+07  3.74764e+06
#
#      y_exit_19 duration_19 entry_hour_19 entry_minute_19 entry_second_19  \
# 0 -1.92815e+07         962            15               2              31
# 1 -1.92659e+07        1756            15               0              32
# 2 -1.91426e+07        2716            14              34              35
# 3  -1.9178e+07           0            15              28              54
# 4  -1.9227e+07           0            15               8               5
#
#   exit_hour_19 exit_minute_19 exit_second_19
# 0           15             18             33
# 1           15             29             48
# 2           15             19             51
# 3           15             28             54
# 4           15              8              5
#
# [5 rows x 380 columns]

# %%
data2.to_csv('data_train_concat.csv')

# %%
# read saved
data2 = pd.read_csv("data_train_concat.csv", index_col=False)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## 1.4 Train/Test Split

# %%
Y = data2['x_exit_19'].between(3750901.5068, 3770901.5068) \
    & data2['y_exit_19'].between((-19268905.6133), -19208905.6133)

# %%
X = data2.drop([x+str(y) for y in range(20) for x in ['Unnamed: 0_', 'hash_', 'trajectory_id_', 'time_entry_', 'time_exit_']] \
    + ['x_exit_19', 'y_exit_19','vmax_19', 'vmin_19', 'vmean_19'] + ['Unnamed: 0'], axis=1)
# X = X.fillna(0)

# %%
from sklearn.model_selection import train_test_split

# %%
X[:5]
# Out:
#    vmax_0  vmin_0  vmean_0  x_entry_0  y_entry_0  x_exit_0  y_exit_0  \
# 0     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 1     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 2     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 3     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 4     NaN     NaN      NaN        NaN        NaN       NaN       NaN
#
#    duration_0  entry_hour_0  entry_minute_0       ...        exit_second_18  \
# 0         NaN           NaN             NaN       ...                   9.0
# 1         NaN           NaN             NaN       ...                  14.0
# 2         NaN           NaN             NaN       ...                   8.0
# 3         NaN           NaN             NaN       ...                   1.0
# 4         NaN           NaN             NaN       ...                  54.0
#
#      x_entry_19    y_entry_19  duration_19  entry_hour_19  entry_minute_19  \
# 0  3.744945e+06 -1.928183e+07          962             15                2
# 1  3.749088e+06 -1.926605e+07         1756             15                0
# 2  3.758738e+06 -1.937594e+07         2716             14               34
# 3  3.767866e+06 -1.917797e+07            0             15               28
# 4  3.747641e+06 -1.922695e+07            0             15                8
#
#    entry_second_19  exit_hour_19  exit_minute_19  exit_second_19
# 0               31            15              18              33
# 1               32            15              29              48
# 2               35            15              19              51
# 3               54            15              28              54
# 4                5            15               8               5
#
# [5 rows x 275 columns]

# %%
train_x, test_x, train_y, test_y = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
(train_x.shape, test_x.shape, train_y.shape, test_y.shape)
# Out:
# ((107250, 275), (26813, 275), (107250,), (26813,))

# %% [markdown]
# # 2. Model Building

# %%
# 488 rounds (0.982671)
models = xgb.XGBClassifier(max_depth=10, learning_rate=0.03, n_estimators=20000, n_jobs=-1,
                           subsample=0.8, colsample_bytree=0.8, seed=420)
#
# models = xgb.XGBClassifier(max_depth=6, learning_rate=0.05, n_estimators=20000,
#                            subsample=0.8, colsample_bytree=0.9, reg_alpha=65, seed=420, n_jobs=-1)

# %%
models.fit(train_x, train_y, eval_metric='auc', early_stopping_rounds=100,
           eval_set=[(train_x, train_y), (test_x, test_y)])
# Out:
# [0]	validation_0-auc:0.981442	validation_1-auc:0.974972
# Multiple eval metrics have been passed: 'validation_1-auc' will be used for early stopping.
#
# Will train until validation_1-auc hasn't improved in 100 rounds.
# [1]	validation_0-auc:0.981056	validation_1-auc:0.97317
# [2]	validation_0-auc:0.983749	validation_1-auc:0.975911
# [3]	validation_0-auc:0.985117	validation_1-auc:0.977088
# [4]	validation_0-auc:0.985721	validation_1-auc:0.977639
# [5]	validation_0-auc:0.986147	validation_1-auc:0.978158
# [6]	validation_0-auc:0.986214	validation_1-auc:0.977672
# [7]	validation_0-auc:0.986643	validation_1-auc:0.978128
# [8]	validation_0-auc:0.986881	validation_1-auc:0.978554
# [9]	validation_0-auc:0.986713	validation_1-auc:0.97786
# [10]	validation_0-auc:0.987076	validation_1-auc:0.978197
# [11]	validation_0-auc:0.987284	validation_1-auc:0.978506
# [12]	validation_0-auc:0.987482	validation_1-auc:0.978766
# [13]	validation_0-auc:0.987722	validation_1-auc:0.979002
# [14]	validation_0-auc:0.987666	validation_1-auc:0.978589
# [15]	validation_0-auc:0.987577	validation_1-auc:0.978116
# [16]	validation_0-auc:0.987779	validation_1-auc:0.978385
# [17]	validation_0-auc:0.988024	validation_1-auc:0.978614
# [18]	validation_0-auc:0.988227	validation_1-auc:0.978656
# [19]	validation_0-auc:0.988084	validation_1-auc:0.978245
# [20]	validation_0-auc:0.988035	validation_1-auc:0.978165
# [21]	validation_0-auc:0.988083	validation_1-auc:0.978116
# [22]	validation_0-auc:0.988292	validation_1-auc:0.97841
# [23]	validation_0-auc:0.988461	validation_1-auc:0.978569
# [24]	validation_0-auc:0.988544	validation_1-auc:0.978585
# [25]	validation_0-auc:0.988522	validation_1-auc:0.978297
# [26]	validation_0-auc:0.98867	validation_1-auc:0.978358
# [27]	validation_0-auc:0.988651	validation_1-auc:0.978257
# [28]	validation_0-auc:0.988608	validation_1-auc:0.978146
# [29]	validation_0-auc:0.988783	validation_1-auc:0.978366
# [30]	validation_0-auc:0.988937	validation_1-auc:0.978525
# [31]	validation_0-auc:0.989113	validation_1-auc:0.978738
# [32]	validation_0-auc:0.989288	validation_1-auc:0.97894
# [33]	validation_0-auc:0.989333	validation_1-auc:0.978808
# [34]	validation_0-auc:0.989356	validation_1-auc:0.978739
# [35]	validation_0-auc:0.989411	validation_1-auc:0.978604
# [36]	validation_0-auc:0.989485	validation_1-auc:0.978601
# [37]	validation_0-auc:0.989464	validation_1-auc:0.978566
# [38]	validation_0-auc:0.989556	validation_1-auc:0.978574
# [39]	validation_0-auc:0.989606	validation_1-auc:0.978438
# [40]	validation_0-auc:0.989595	validation_1-auc:0.97826
# [41]	validation_0-auc:0.989762	validation_1-auc:0.97846
# [42]	validation_0-auc:0.989897	validation_1-auc:0.97861
# [43]	validation_0-auc:0.989871	validation_1-auc:0.97846
# [44]	validation_0-auc:0.990008	validation_1-auc:0.978584
# [45]	validation_0-auc:0.990137	validation_1-auc:0.978722
# [46]	validation_0-auc:0.990261	validation_1-auc:0.978867
# [47]	validation_0-auc:0.990353	validation_1-auc:0.978996
# [48]	validation_0-auc:0.990408	validation_1-auc:0.97893
# [49]	validation_0-auc:0.990505	validation_1-auc:0.979079
# [50]	validation_0-auc:0.99059	validation_1-auc:0.979168
# [51]	validation_0-auc:0.990695	validation_1-auc:0.979322
# [52]	validation_0-auc:0.990789	validation_1-auc:0.979465
# [53]	validation_0-auc:0.990897	validation_1-auc:0.97959
# [54]	validation_0-auc:0.990897	validation_1-auc:0.979575
# [55]	validation_0-auc:0.991004	validation_1-auc:0.979702
# [56]	validation_0-auc:0.991052	validation_1-auc:0.979633
# [57]	validation_0-auc:0.991129	validation_1-auc:0.979714
# [58]	validation_0-auc:0.991171	validation_1-auc:0.979648
# [59]	validation_0-auc:0.991222	validation_1-auc:0.979661
# [60]	validation_0-auc:0.991318	validation_1-auc:0.979755
# [61]	validation_0-auc:0.991408	validation_1-auc:0.979811
# [62]	validation_0-auc:0.991494	validation_1-auc:0.979916
# [63]	validation_0-auc:0.991581	validation_1-auc:0.980011
# [64]	validation_0-auc:0.991677	validation_1-auc:0.980089
# [65]	validation_0-auc:0.991728	validation_1-auc:0.980081
# [66]	validation_0-auc:0.991791	validation_1-auc:0.980069
# [67]	validation_0-auc:0.991879	validation_1-auc:0.980193
# [68]	validation_0-auc:0.991964	validation_1-auc:0.980256
# [69]	validation_0-auc:0.992054	validation_1-auc:0.980348
# [70]	validation_0-auc:0.99213	validation_1-auc:0.980426
# [71]	validation_0-auc:0.992158	validation_1-auc:0.980409
# [72]	validation_0-auc:0.992222	validation_1-auc:0.980453
# [73]	validation_0-auc:0.992276	validation_1-auc:0.980437
# [74]	validation_0-auc:0.992296	validation_1-auc:0.980419
# [75]	validation_0-auc:0.992315	validation_1-auc:0.980431
# [76]	validation_0-auc:0.992343	validation_1-auc:0.980399
# [77]	validation_0-auc:0.992431	validation_1-auc:0.980468
# [78]	validation_0-auc:0.992521	validation_1-auc:0.980517
# [79]	validation_0-auc:0.992566	validation_1-auc:0.980472
# [80]	validation_0-auc:0.992638	validation_1-auc:0.980512
# [81]	validation_0-auc:0.992698	validation_1-auc:0.980578
# [82]	validation_0-auc:0.992771	validation_1-auc:0.980661
# [83]	validation_0-auc:0.992845	validation_1-auc:0.98069
# [84]	validation_0-auc:0.992921	validation_1-auc:0.980763
# [85]	validation_0-auc:0.992955	validation_1-auc:0.980733
# [86]	validation_0-auc:0.992991	validation_1-auc:0.980721
# [87]	validation_0-auc:0.99307	validation_1-auc:0.980782
# [88]	validation_0-auc:0.993137	validation_1-auc:0.980843
# [89]	validation_0-auc:0.993197	validation_1-auc:0.980914
# [90]	validation_0-auc:0.99325	validation_1-auc:0.980952
# [91]	validation_0-auc:0.993314	validation_1-auc:0.98096
# [92]	validation_0-auc:0.993377	validation_1-auc:0.981003
# [93]	validation_0-auc:0.993443	validation_1-auc:0.981014
# [94]	validation_0-auc:0.993487	validation_1-auc:0.981008
# [95]	validation_0-auc:0.993529	validation_1-auc:0.981044
# [96]	validation_0-auc:0.993582	validation_1-auc:0.981093
# [97]	validation_0-auc:0.993645	validation_1-auc:0.981135
# [98]	validation_0-auc:0.993683	validation_1-auc:0.981189
# [99]	validation_0-auc:0.993734	validation_1-auc:0.981227
# [100]	validation_0-auc:0.993789	validation_1-auc:0.98124
# [101]	validation_0-auc:0.993843	validation_1-auc:0.981275
# [102]	validation_0-auc:0.993866	validation_1-auc:0.981255
# [103]	validation_0-auc:0.993922	validation_1-auc:0.981305
# [104]	validation_0-auc:0.993973	validation_1-auc:0.981353
# [105]	validation_0-auc:0.993994	validation_1-auc:0.981344
# [106]	validation_0-auc:0.994038	validation_1-auc:0.981374
# [107]	validation_0-auc:0.994081	validation_1-auc:0.981402
# [108]	validation_0-auc:0.99412	validation_1-auc:0.981407
# [109]	validation_0-auc:0.994164	validation_1-auc:0.981437
# [110]	validation_0-auc:0.994203	validation_1-auc:0.981462
# [111]	validation_0-auc:0.994252	validation_1-auc:0.981503
# [112]	validation_0-auc:0.994291	validation_1-auc:0.981539
# [113]	validation_0-auc:0.994326	validation_1-auc:0.981564
# [114]	validation_0-auc:0.994347	validation_1-auc:0.981565
# [115]	validation_0-auc:0.99439	validation_1-auc:0.981582
# [116]	validation_0-auc:0.994434	validation_1-auc:0.98161
# [117]	validation_0-auc:0.994462	validation_1-auc:0.981639
# [118]	validation_0-auc:0.994501	validation_1-auc:0.981663
# [119]	validation_0-auc:0.99454	validation_1-auc:0.981671
# [120]	validation_0-auc:0.99458	validation_1-auc:0.981704
# [121]	validation_0-auc:0.994612	validation_1-auc:0.981692
# [122]	validation_0-auc:0.994653	validation_1-auc:0.981692
# [123]	validation_0-auc:0.994693	validation_1-auc:0.981709
# [124]	validation_0-auc:0.994722	validation_1-auc:0.981706
# [125]	validation_0-auc:0.994766	validation_1-auc:0.981731
# [126]	validation_0-auc:0.994799	validation_1-auc:0.98175
# [127]	validation_0-auc:0.994838	validation_1-auc:0.981775
# [128]	validation_0-auc:0.994874	validation_1-auc:0.981803
# [129]	validation_0-auc:0.994905	validation_1-auc:0.981835
# [130]	validation_0-auc:0.994924	validation_1-auc:0.981835
# [131]	validation_0-auc:0.994952	validation_1-auc:0.981856
# [132]	validation_0-auc:0.994981	validation_1-auc:0.981862
# [133]	validation_0-auc:0.995007	validation_1-auc:0.981866
# [134]	validation_0-auc:0.995041	validation_1-auc:0.981874
# [135]	validation_0-auc:0.995076	validation_1-auc:0.981897
# [136]	validation_0-auc:0.995098	validation_1-auc:0.981902
# [137]	validation_0-auc:0.995129	validation_1-auc:0.981914
# [138]	validation_0-auc:0.995155	validation_1-auc:0.981927
# [139]	validation_0-auc:0.995182	validation_1-auc:0.981949
# [140]	validation_0-auc:0.995216	validation_1-auc:0.981951
# [141]	validation_0-auc:0.995257	validation_1-auc:0.981956
# [142]	validation_0-auc:0.995286	validation_1-auc:0.981971
# [143]	validation_0-auc:0.995315	validation_1-auc:0.981981
# [144]	validation_0-auc:0.995346	validation_1-auc:0.981999
# [145]	validation_0-auc:0.995372	validation_1-auc:0.982018
# [146]	validation_0-auc:0.995415	validation_1-auc:0.982027
# [147]	validation_0-auc:0.995442	validation_1-auc:0.982026
# [148]	validation_0-auc:0.995481	validation_1-auc:0.982053
# [149]	validation_0-auc:0.995506	validation_1-auc:0.982083
# [150]	validation_0-auc:0.99553	validation_1-auc:0.982084
# [151]	validation_0-auc:0.995554	validation_1-auc:0.982095
# [152]	validation_0-auc:0.995592	validation_1-auc:0.982097
# [153]	validation_0-auc:0.995626	validation_1-auc:0.982091
# [154]	validation_0-auc:0.995658	validation_1-auc:0.982092
# [155]	validation_0-auc:0.995681	validation_1-auc:0.982086
# [156]	validation_0-auc:0.995706	validation_1-auc:0.98211
# [157]	validation_0-auc:0.995738	validation_1-auc:0.982102
# [158]	validation_0-auc:0.995758	validation_1-auc:0.982098
# [159]	validation_0-auc:0.995777	validation_1-auc:0.982092
# [160]	validation_0-auc:0.995805	validation_1-auc:0.982116
# [161]	validation_0-auc:0.99583	validation_1-auc:0.982134
# [162]	validation_0-auc:0.995866	validation_1-auc:0.982146
# [163]	validation_0-auc:0.995888	validation_1-auc:0.982153
# [164]	validation_0-auc:0.995907	validation_1-auc:0.982158
# [165]	validation_0-auc:0.995931	validation_1-auc:0.982164
# [166]	validation_0-auc:0.995953	validation_1-auc:0.982165
# [167]	validation_0-auc:0.995975	validation_1-auc:0.982171
# [168]	validation_0-auc:0.996012	validation_1-auc:0.982182
# [169]	validation_0-auc:0.996034	validation_1-auc:0.982198
# [170]	validation_0-auc:0.996048	validation_1-auc:0.982205
# [171]	validation_0-auc:0.996072	validation_1-auc:0.982218
# [172]	validation_0-auc:0.996116	validation_1-auc:0.982229
# [173]	validation_0-auc:0.996138	validation_1-auc:0.982239
# [174]	validation_0-auc:0.996155	validation_1-auc:0.982244
# [175]	validation_0-auc:0.996186	validation_1-auc:0.982252
# [176]	validation_0-auc:0.996203	validation_1-auc:0.982257
# [177]	validation_0-auc:0.996225	validation_1-auc:0.982266
# [178]	validation_0-auc:0.996247	validation_1-auc:0.982263
# [179]	validation_0-auc:0.996266	validation_1-auc:0.98226
# [180]	validation_0-auc:0.996307	validation_1-auc:0.98227
# [181]	validation_0-auc:0.996322	validation_1-auc:0.982268
# [182]	validation_0-auc:0.996346	validation_1-auc:0.982277
# [183]	validation_0-auc:0.996369	validation_1-auc:0.982277
# [184]	validation_0-auc:0.996393	validation_1-auc:0.982284
# [185]	validation_0-auc:0.996419	validation_1-auc:0.982296
# [186]	validation_0-auc:0.996445	validation_1-auc:0.982296
# [187]	validation_0-auc:0.996479	validation_1-auc:0.982307
# [188]	validation_0-auc:0.996494	validation_1-auc:0.982322
# [189]	validation_0-auc:0.99651	validation_1-auc:0.98233
# [190]	validation_0-auc:0.996531	validation_1-auc:0.982338
# [191]	validation_0-auc:0.996538	validation_1-auc:0.982347
# [192]	validation_0-auc:0.996552	validation_1-auc:0.982352
# [193]	validation_0-auc:0.996598	validation_1-auc:0.98236
# [194]	validation_0-auc:0.996616	validation_1-auc:0.982361
# [195]	validation_0-auc:0.996659	validation_1-auc:0.982374
# [196]	validation_0-auc:0.996687	validation_1-auc:0.982367
# [197]	validation_0-auc:0.9967	validation_1-auc:0.982372
# [198]	validation_0-auc:0.996712	validation_1-auc:0.982369
# [199]	validation_0-auc:0.996731	validation_1-auc:0.982376
# [200]	validation_0-auc:0.996759	validation_1-auc:0.982378
# [201]	validation_0-auc:0.996786	validation_1-auc:0.982372
# [202]	validation_0-auc:0.996808	validation_1-auc:0.982377
# [203]	validation_0-auc:0.996823	validation_1-auc:0.982375
# [204]	validation_0-auc:0.99684	validation_1-auc:0.982369
# [205]	validation_0-auc:0.996866	validation_1-auc:0.982372
# [206]	validation_0-auc:0.996892	validation_1-auc:0.982379
# [207]	validation_0-auc:0.996907	validation_1-auc:0.982383
# [208]	validation_0-auc:0.996928	validation_1-auc:0.982389
# [209]	validation_0-auc:0.996957	validation_1-auc:0.982392
# [210]	validation_0-auc:0.996975	validation_1-auc:0.9824
# [211]	validation_0-auc:0.996985	validation_1-auc:0.982404
# [212]	validation_0-auc:0.996997	validation_1-auc:0.982393
# [213]	validation_0-auc:0.997008	validation_1-auc:0.982401
# [214]	validation_0-auc:0.997026	validation_1-auc:0.982409
# [215]	validation_0-auc:0.997039	validation_1-auc:0.982413
# [216]	validation_0-auc:0.997048	validation_1-auc:0.982412
# [217]	validation_0-auc:0.997061	validation_1-auc:0.982417
# [218]	validation_0-auc:0.997081	validation_1-auc:0.982416
# [219]	validation_0-auc:0.997095	validation_1-auc:0.982413
# [220]	validation_0-auc:0.99711	validation_1-auc:0.98242
# [221]	validation_0-auc:0.997116	validation_1-auc:0.98242
# [222]	validation_0-auc:0.997122	validation_1-auc:0.982423
# [223]	validation_0-auc:0.997143	validation_1-auc:0.982421
# [224]	validation_0-auc:0.997154	validation_1-auc:0.982421
# [225]	validation_0-auc:0.997163	validation_1-auc:0.982422
# [226]	validation_0-auc:0.997175	validation_1-auc:0.982416
# [227]	validation_0-auc:0.997195	validation_1-auc:0.982417
# [228]	validation_0-auc:0.997207	validation_1-auc:0.982412
# [229]	validation_0-auc:0.997219	validation_1-auc:0.982416
# [230]	validation_0-auc:0.997227	validation_1-auc:0.982416
# [231]	validation_0-auc:0.997249	validation_1-auc:0.98242
# [232]	validation_0-auc:0.997265	validation_1-auc:0.982422
# [233]	validation_0-auc:0.997284	validation_1-auc:0.98242
# [234]	validation_0-auc:0.997294	validation_1-auc:0.982419
# [235]	validation_0-auc:0.997311	validation_1-auc:0.982421
# [236]	validation_0-auc:0.997325	validation_1-auc:0.982425
# [237]	validation_0-auc:0.99734	validation_1-auc:0.982425
# [238]	validation_0-auc:0.997363	validation_1-auc:0.982441
# [239]	validation_0-auc:0.997387	validation_1-auc:0.982439
# [240]	validation_0-auc:0.997402	validation_1-auc:0.98244
# [241]	validation_0-auc:0.997419	validation_1-auc:0.982435
# [242]	validation_0-auc:0.997429	validation_1-auc:0.982443
# [243]	validation_0-auc:0.997447	validation_1-auc:0.982436
# [244]	validation_0-auc:0.997459	validation_1-auc:0.982435
# [245]	validation_0-auc:0.997468	validation_1-auc:0.982435
# [246]	validation_0-auc:0.997484	validation_1-auc:0.982435
# [247]	validation_0-auc:0.997496	validation_1-auc:0.98244
# [248]	validation_0-auc:0.997511	validation_1-auc:0.982436
# [249]	validation_0-auc:0.997519	validation_1-auc:0.982436
# [250]	validation_0-auc:0.997536	validation_1-auc:0.982436
# [251]	validation_0-auc:0.997549	validation_1-auc:0.982433
# [252]	validation_0-auc:0.997564	validation_1-auc:0.982434
# [253]	validation_0-auc:0.997579	validation_1-auc:0.982451
# [254]	validation_0-auc:0.997582	validation_1-auc:0.982451
# [255]	validation_0-auc:0.997588	validation_1-auc:0.98245
# [256]	validation_0-auc:0.997596	validation_1-auc:0.982445
# [257]	validation_0-auc:0.997609	validation_1-auc:0.982443
# [258]	validation_0-auc:0.997622	validation_1-auc:0.982439
# [259]	validation_0-auc:0.997627	validation_1-auc:0.982437
# [260]	validation_0-auc:0.997638	validation_1-auc:0.982434
# [261]	validation_0-auc:0.997649	validation_1-auc:0.982433
# [262]	validation_0-auc:0.997661	validation_1-auc:0.982431
# [263]	validation_0-auc:0.997673	validation_1-auc:0.982435
# [264]	validation_0-auc:0.997683	validation_1-auc:0.982442
# [265]	validation_0-auc:0.997689	validation_1-auc:0.982439
# [266]	validation_0-auc:0.99772	validation_1-auc:0.982452
# [267]	validation_0-auc:0.99773	validation_1-auc:0.982467
# [268]	validation_0-auc:0.997747	validation_1-auc:0.982465
# [269]	validation_0-auc:0.997754	validation_1-auc:0.982468
# [270]	validation_0-auc:0.997759	validation_1-auc:0.982473
# [271]	validation_0-auc:0.997781	validation_1-auc:0.982476
# [272]	validation_0-auc:0.997789	validation_1-auc:0.982474
# [273]	validation_0-auc:0.997802	validation_1-auc:0.982473
# [274]	validation_0-auc:0.997812	validation_1-auc:0.982473
# [275]	validation_0-auc:0.99782	validation_1-auc:0.982474
# [276]	validation_0-auc:0.997829	validation_1-auc:0.982486
# [277]	validation_0-auc:0.997835	validation_1-auc:0.982486
# [278]	validation_0-auc:0.997839	validation_1-auc:0.982487
# [279]	validation_0-auc:0.99787	validation_1-auc:0.982481
# [280]	validation_0-auc:0.997885	validation_1-auc:0.982476
# [281]	validation_0-auc:0.997896	validation_1-auc:0.98248
# [282]	validation_0-auc:0.997908	validation_1-auc:0.982486
# [283]	validation_0-auc:0.997916	validation_1-auc:0.982485
# [284]	validation_0-auc:0.997923	validation_1-auc:0.982483
# [285]	validation_0-auc:0.99794	validation_1-auc:0.982488
# [286]	validation_0-auc:0.997955	validation_1-auc:0.982487
# [287]	validation_0-auc:0.997972	validation_1-auc:0.982485
# [288]	validation_0-auc:0.997991	validation_1-auc:0.982483
# [289]	validation_0-auc:0.998019	validation_1-auc:0.982485
# [290]	validation_0-auc:0.998038	validation_1-auc:0.982491
# [291]	validation_0-auc:0.998042	validation_1-auc:0.982493
# [292]	validation_0-auc:0.998051	validation_1-auc:0.982493
# [293]	validation_0-auc:0.998057	validation_1-auc:0.982493
# [294]	validation_0-auc:0.998076	validation_1-auc:0.982492
# [295]	validation_0-auc:0.998092	validation_1-auc:0.982496
# [296]	validation_0-auc:0.998097	validation_1-auc:0.982502
# [297]	validation_0-auc:0.998109	validation_1-auc:0.9825
# [298]	validation_0-auc:0.998118	validation_1-auc:0.982505
# [299]	validation_0-auc:0.998125	validation_1-auc:0.982503
# [300]	validation_0-auc:0.99813	validation_1-auc:0.982504
# [301]	validation_0-auc:0.998133	validation_1-auc:0.982508
# [302]	validation_0-auc:0.998148	validation_1-auc:0.982511
# [303]	validation_0-auc:0.99818	validation_1-auc:0.982525
# [304]	validation_0-auc:0.998188	validation_1-auc:0.982528
# [305]	validation_0-auc:0.998202	validation_1-auc:0.982523
# [306]	validation_0-auc:0.998225	validation_1-auc:0.982533
# [307]	validation_0-auc:0.998232	validation_1-auc:0.982534
# [308]	validation_0-auc:0.998253	validation_1-auc:0.982537
# [309]	validation_0-auc:0.998264	validation_1-auc:0.982539
# [310]	validation_0-auc:0.998274	validation_1-auc:0.982545
# [311]	validation_0-auc:0.998285	validation_1-auc:0.982545
# [312]	validation_0-auc:0.998292	validation_1-auc:0.982547
# [313]	validation_0-auc:0.998307	validation_1-auc:0.98255
# [314]	validation_0-auc:0.998315	validation_1-auc:0.98255
# [315]	validation_0-auc:0.998323	validation_1-auc:0.982551
# [316]	validation_0-auc:0.99833	validation_1-auc:0.982553
# [317]	validation_0-auc:0.998336	validation_1-auc:0.982559
# [318]	validation_0-auc:0.998354	validation_1-auc:0.982548
# [319]	validation_0-auc:0.998358	validation_1-auc:0.98255
# [320]	validation_0-auc:0.998367	validation_1-auc:0.982548
# [321]	validation_0-auc:0.998378	validation_1-auc:0.982544
# [322]	validation_0-auc:0.998387	validation_1-auc:0.982545
# [323]	validation_0-auc:0.998393	validation_1-auc:0.982543
# [324]	validation_0-auc:0.998404	validation_1-auc:0.982544
# [325]	validation_0-auc:0.998417	validation_1-auc:0.982535
# [326]	validation_0-auc:0.998424	validation_1-auc:0.982535
# [327]	validation_0-auc:0.998446	validation_1-auc:0.98254
# [328]	validation_0-auc:0.998449	validation_1-auc:0.982539
# [329]	validation_0-auc:0.998468	validation_1-auc:0.982536
# [330]	validation_0-auc:0.998483	validation_1-auc:0.982534
# [331]	validation_0-auc:0.998496	validation_1-auc:0.982531
# [332]	validation_0-auc:0.998505	validation_1-auc:0.982532
# [333]	validation_0-auc:0.998509	validation_1-auc:0.98253
# [334]	validation_0-auc:0.998512	validation_1-auc:0.98253
# [335]	validation_0-auc:0.998525	validation_1-auc:0.982528
# [336]	validation_0-auc:0.998528	validation_1-auc:0.982529
# [337]	validation_0-auc:0.998533	validation_1-auc:0.982531
# [338]	validation_0-auc:0.998541	validation_1-auc:0.982532
# [339]	validation_0-auc:0.998543	validation_1-auc:0.982528
# [340]	validation_0-auc:0.99857	validation_1-auc:0.982532
# [341]	validation_0-auc:0.998573	validation_1-auc:0.982532
# [342]	validation_0-auc:0.998577	validation_1-auc:0.982528
# [343]	validation_0-auc:0.998588	validation_1-auc:0.982533
# [344]	validation_0-auc:0.998594	validation_1-auc:0.982531
# [345]	validation_0-auc:0.998609	validation_1-auc:0.982536
# [346]	validation_0-auc:0.998624	validation_1-auc:0.982541
# [347]	validation_0-auc:0.998633	validation_1-auc:0.982539
# [348]	validation_0-auc:0.99864	validation_1-auc:0.982544
# [349]	validation_0-auc:0.998651	validation_1-auc:0.98254
# [350]	validation_0-auc:0.998655	validation_1-auc:0.982539
# [351]	validation_0-auc:0.99866	validation_1-auc:0.982539
# [352]	validation_0-auc:0.998665	validation_1-auc:0.982531
# [353]	validation_0-auc:0.998679	validation_1-auc:0.982537
# [354]	validation_0-auc:0.998682	validation_1-auc:0.982534
# [355]	validation_0-auc:0.998684	validation_1-auc:0.982535
# [356]	validation_0-auc:0.998699	validation_1-auc:0.982537
# [357]	validation_0-auc:0.998705	validation_1-auc:0.98254
# [358]	validation_0-auc:0.998714	validation_1-auc:0.982543
# [359]	validation_0-auc:0.998719	validation_1-auc:0.982548
# [360]	validation_0-auc:0.998727	validation_1-auc:0.982545
# [361]	validation_0-auc:0.998735	validation_1-auc:0.982543
# [362]	validation_0-auc:0.998737	validation_1-auc:0.982543
# [363]	validation_0-auc:0.998747	validation_1-auc:0.982542
# [364]	validation_0-auc:0.998758	validation_1-auc:0.982543
# [365]	validation_0-auc:0.998769	validation_1-auc:0.982544
# [366]	validation_0-auc:0.998773	validation_1-auc:0.982546
# [367]	validation_0-auc:0.998796	validation_1-auc:0.982554
# [368]	validation_0-auc:0.998809	validation_1-auc:0.982554
# [369]	validation_0-auc:0.998823	validation_1-auc:0.982553
# [370]	validation_0-auc:0.998831	validation_1-auc:0.982555
# [371]	validation_0-auc:0.998833	validation_1-auc:0.982554
# [372]	validation_0-auc:0.998843	validation_1-auc:0.982554
# [373]	validation_0-auc:0.998852	validation_1-auc:0.98256
# [374]	validation_0-auc:0.99886	validation_1-auc:0.982558
# [375]	validation_0-auc:0.998867	validation_1-auc:0.982553
# [376]	validation_0-auc:0.998876	validation_1-auc:0.982552
# [377]	validation_0-auc:0.998881	validation_1-auc:0.982549
# [378]	validation_0-auc:0.998883	validation_1-auc:0.982545
# [379]	validation_0-auc:0.998895	validation_1-auc:0.982556
# [380]	validation_0-auc:0.9989	validation_1-auc:0.982561
# [381]	validation_0-auc:0.998915	validation_1-auc:0.982557
# [382]	validation_0-auc:0.998918	validation_1-auc:0.98256
# [383]	validation_0-auc:0.998927	validation_1-auc:0.982559
# [384]	validation_0-auc:0.998941	validation_1-auc:0.982561
# [385]	validation_0-auc:0.998946	validation_1-auc:0.982558
# [386]	validation_0-auc:0.998948	validation_1-auc:0.982557
# [387]	validation_0-auc:0.998952	validation_1-auc:0.982559
# [388]	validation_0-auc:0.998962	validation_1-auc:0.982565
# [389]	validation_0-auc:0.998968	validation_1-auc:0.982567
# [390]	validation_0-auc:0.998979	validation_1-auc:0.982561
# [391]	validation_0-auc:0.998985	validation_1-auc:0.98257
# [392]	validation_0-auc:0.998994	validation_1-auc:0.98257
# [393]	validation_0-auc:0.998997	validation_1-auc:0.98257
# [394]	validation_0-auc:0.999002	validation_1-auc:0.982574
# [395]	validation_0-auc:0.999012	validation_1-auc:0.982577
# [396]	validation_0-auc:0.999025	validation_1-auc:0.982577
# [397]	validation_0-auc:0.999031	validation_1-auc:0.982584
# [398]	validation_0-auc:0.999034	validation_1-auc:0.982584
# [399]	validation_0-auc:0.99905	validation_1-auc:0.982581
# [400]	validation_0-auc:0.999056	validation_1-auc:0.982583
# [401]	validation_0-auc:0.999062	validation_1-auc:0.982579
# [402]	validation_0-auc:0.999065	validation_1-auc:0.982578
# [403]	validation_0-auc:0.999067	validation_1-auc:0.982575
# [404]	validation_0-auc:0.99908	validation_1-auc:0.982575
# [405]	validation_0-auc:0.99909	validation_1-auc:0.982582
# [406]	validation_0-auc:0.999093	validation_1-auc:0.982585
# [407]	validation_0-auc:0.999101	validation_1-auc:0.982596
# [408]	validation_0-auc:0.999117	validation_1-auc:0.982599
# [409]	validation_0-auc:0.999127	validation_1-auc:0.982598
# [410]	validation_0-auc:0.999129	validation_1-auc:0.982597
# [411]	validation_0-auc:0.999131	validation_1-auc:0.98259
# [412]	validation_0-auc:0.999137	validation_1-auc:0.982592
# [413]	validation_0-auc:0.999142	validation_1-auc:0.982601
# [414]	validation_0-auc:0.999156	validation_1-auc:0.982599
# [415]	validation_0-auc:0.999165	validation_1-auc:0.982604
# [416]	validation_0-auc:0.99917	validation_1-auc:0.982603
# [417]	validation_0-auc:0.999173	validation_1-auc:0.982601
# [418]	validation_0-auc:0.999181	validation_1-auc:0.9826
# [419]	validation_0-auc:0.999183	validation_1-auc:0.9826
# [420]	validation_0-auc:0.999185	validation_1-auc:0.982595
# [421]	validation_0-auc:0.999192	validation_1-auc:0.982603
# [422]	validation_0-auc:0.999198	validation_1-auc:0.982605
# [423]	validation_0-auc:0.999203	validation_1-auc:0.982605
# [424]	validation_0-auc:0.999205	validation_1-auc:0.9826
# [425]	validation_0-auc:0.999208	validation_1-auc:0.982596
# [426]	validation_0-auc:0.99921	validation_1-auc:0.982596
# [427]	validation_0-auc:0.999221	validation_1-auc:0.982597
# [428]	validation_0-auc:0.999224	validation_1-auc:0.982598
# [429]	validation_0-auc:0.999228	validation_1-auc:0.982596
# [430]	validation_0-auc:0.99923	validation_1-auc:0.982598
# [431]	validation_0-auc:0.999236	validation_1-auc:0.982606
# [432]	validation_0-auc:0.999243	validation_1-auc:0.982607
# [433]	validation_0-auc:0.99925	validation_1-auc:0.982611
# [434]	validation_0-auc:0.999254	validation_1-auc:0.982614
# [435]	validation_0-auc:0.999265	validation_1-auc:0.982615
# [436]	validation_0-auc:0.999269	validation_1-auc:0.982613
# [437]	validation_0-auc:0.999277	validation_1-auc:0.982612
# [438]	validation_0-auc:0.999281	validation_1-auc:0.982613
# [439]	validation_0-auc:0.999284	validation_1-auc:0.982612
# [440]	validation_0-auc:0.999289	validation_1-auc:0.982614
# [441]	validation_0-auc:0.999291	validation_1-auc:0.982611
# [442]	validation_0-auc:0.999303	validation_1-auc:0.982607
# [443]	validation_0-auc:0.999314	validation_1-auc:0.982609
# [444]	validation_0-auc:0.99932	validation_1-auc:0.982611
# [445]	validation_0-auc:0.999323	validation_1-auc:0.982616
# [446]	validation_0-auc:0.999331	validation_1-auc:0.982622
# [447]	validation_0-auc:0.999333	validation_1-auc:0.982626
# [448]	validation_0-auc:0.999336	validation_1-auc:0.982632
# [449]	validation_0-auc:0.999339	validation_1-auc:0.982633
# [450]	validation_0-auc:0.999344	validation_1-auc:0.982632
# [451]	validation_0-auc:0.999353	validation_1-auc:0.982639
# [452]	validation_0-auc:0.999359	validation_1-auc:0.982638
# [453]	validation_0-auc:0.99936	validation_1-auc:0.982639
# [454]	validation_0-auc:0.999366	validation_1-auc:0.982645
# [455]	validation_0-auc:0.999369	validation_1-auc:0.982642
# [456]	validation_0-auc:0.999374	validation_1-auc:0.982648
# [457]	validation_0-auc:0.999377	validation_1-auc:0.982651
# [458]	validation_0-auc:0.999384	validation_1-auc:0.982649
# [459]	validation_0-auc:0.999386	validation_1-auc:0.98265
# [460]	validation_0-auc:0.999387	validation_1-auc:0.982648
# [461]	validation_0-auc:0.99939	validation_1-auc:0.982643
# [462]	validation_0-auc:0.999396	validation_1-auc:0.982642
# [463]	validation_0-auc:0.999401	validation_1-auc:0.982637
# [464]	validation_0-auc:0.999405	validation_1-auc:0.982633
# [465]	validation_0-auc:0.999408	validation_1-auc:0.982635
# [466]	validation_0-auc:0.999412	validation_1-auc:0.982639
# [467]	validation_0-auc:0.99942	validation_1-auc:0.982638
# [468]	validation_0-auc:0.999421	validation_1-auc:0.982636
# [469]	validation_0-auc:0.999423	validation_1-auc:0.982636
# [470]	validation_0-auc:0.999427	validation_1-auc:0.98264
# [471]	validation_0-auc:0.999432	validation_1-auc:0.982642
# [472]	validation_0-auc:0.999432	validation_1-auc:0.982643
# [473]	validation_0-auc:0.999437	validation_1-auc:0.982644
# [474]	validation_0-auc:0.999443	validation_1-auc:0.982652
# [475]	validation_0-auc:0.999445	validation_1-auc:0.982652
# [476]	validation_0-auc:0.999449	validation_1-auc:0.982655
# [477]	validation_0-auc:0.999452	validation_1-auc:0.982658
# [478]	validation_0-auc:0.999455	validation_1-auc:0.982658
# [479]	validation_0-auc:0.999459	validation_1-auc:0.982664
# [480]	validation_0-auc:0.99946	validation_1-auc:0.982667
# [481]	validation_0-auc:0.999465	validation_1-auc:0.982664
# [482]	validation_0-auc:0.999468	validation_1-auc:0.98267
# [483]	validation_0-auc:0.999473	validation_1-auc:0.982659
# [484]	validation_0-auc:0.999482	validation_1-auc:0.982652
# [485]	validation_0-auc:0.999483	validation_1-auc:0.982654
# [486]	validation_0-auc:0.999494	validation_1-auc:0.982657
# [487]	validation_0-auc:0.999496	validation_1-auc:0.982669
# [488]	validation_0-auc:0.999503	validation_1-auc:0.982671
# [489]	validation_0-auc:0.999507	validation_1-auc:0.982667
# [490]	validation_0-auc:0.999514	validation_1-auc:0.98266
# [491]	validation_0-auc:0.999518	validation_1-auc:0.982659
# [492]	validation_0-auc:0.999522	validation_1-auc:0.98266
# [493]	validation_0-auc:0.999528	validation_1-auc:0.982658
# [494]	validation_0-auc:0.99953	validation_1-auc:0.982655
# [495]	validation_0-auc:0.999534	validation_1-auc:0.982661
# [496]	validation_0-auc:0.999535	validation_1-auc:0.982664
# [497]	validation_0-auc:0.999541	validation_1-auc:0.982662
# [498]	validation_0-auc:0.999544	validation_1-auc:0.982659
# [499]	validation_0-auc:0.999545	validation_1-auc:0.982655
# [500]	validation_0-auc:0.999548	validation_1-auc:0.982653
# [501]	validation_0-auc:0.999555	validation_1-auc:0.982649
# [502]	validation_0-auc:0.999559	validation_1-auc:0.982652
# [503]	validation_0-auc:0.999561	validation_1-auc:0.982648
# [504]	validation_0-auc:0.999562	validation_1-auc:0.982646
# [505]	validation_0-auc:0.999565	validation_1-auc:0.982649
# [506]	validation_0-auc:0.999573	validation_1-auc:0.98265
# [507]	validation_0-auc:0.999575	validation_1-auc:0.982657
# [508]	validation_0-auc:0.99958	validation_1-auc:0.982662
# [509]	validation_0-auc:0.999582	validation_1-auc:0.982665
# [510]	validation_0-auc:0.999586	validation_1-auc:0.982669
# [511]	validation_0-auc:0.999589	validation_1-auc:0.982667
# [512]	validation_0-auc:0.999593	validation_1-auc:0.982667
# [513]	validation_0-auc:0.999595	validation_1-auc:0.982659
# [514]	validation_0-auc:0.999597	validation_1-auc:0.982661
# [515]	validation_0-auc:0.999604	validation_1-auc:0.982653
# [516]	validation_0-auc:0.999608	validation_1-auc:0.982649
# [517]	validation_0-auc:0.999613	validation_1-auc:0.982654
# [518]	validation_0-auc:0.999614	validation_1-auc:0.982653
# [519]	validation_0-auc:0.999618	validation_1-auc:0.982653
# [520]	validation_0-auc:0.999626	validation_1-auc:0.982655
# [521]	validation_0-auc:0.999629	validation_1-auc:0.982659
# [522]	validation_0-auc:0.999635	validation_1-auc:0.982655
# [523]	validation_0-auc:0.999638	validation_1-auc:0.982653
# [524]	validation_0-auc:0.99964	validation_1-auc:0.982654
# [525]	validation_0-auc:0.999644	validation_1-auc:0.982654
# [526]	validation_0-auc:0.999649	validation_1-auc:0.982652
# [527]	validation_0-auc:0.999652	validation_1-auc:0.982652
# [528]	validation_0-auc:0.999658	validation_1-auc:0.982651
# [529]	validation_0-auc:0.999663	validation_1-auc:0.982643
# [530]	validation_0-auc:0.999664	validation_1-auc:0.982647
# [531]	validation_0-auc:0.999665	validation_1-auc:0.982644
# [532]	validation_0-auc:0.99967	validation_1-auc:0.982644
# [533]	validation_0-auc:0.999672	validation_1-auc:0.982645
# [534]	validation_0-auc:0.999677	validation_1-auc:0.982648
# [535]	validation_0-auc:0.999679	validation_1-auc:0.982649
# [536]	validation_0-auc:0.999683	validation_1-auc:0.982654
# [537]	validation_0-auc:0.999685	validation_1-auc:0.982652
# [538]	validation_0-auc:0.999688	validation_1-auc:0.982649
# [539]	validation_0-auc:0.999689	validation_1-auc:0.98265
# [540]	validation_0-auc:0.999694	validation_1-auc:0.982648
# [541]	validation_0-auc:0.999697	validation_1-auc:0.982642
# [542]	validation_0-auc:0.999698	validation_1-auc:0.982639
# [543]	validation_0-auc:0.999701	validation_1-auc:0.982633
# [544]	validation_0-auc:0.999703	validation_1-auc:0.98263
# [545]	validation_0-auc:0.999704	validation_1-auc:0.982627
# [546]	validation_0-auc:0.999706	validation_1-auc:0.982632
# [547]	validation_0-auc:0.999707	validation_1-auc:0.982633
# [548]	validation_0-auc:0.999709	validation_1-auc:0.982636
# [549]	validation_0-auc:0.999711	validation_1-auc:0.982635
# [550]	validation_0-auc:0.999712	validation_1-auc:0.982635
# [551]	validation_0-auc:0.999715	validation_1-auc:0.982641
# [552]	validation_0-auc:0.999717	validation_1-auc:0.982642
# [553]	validation_0-auc:0.999722	validation_1-auc:0.98264
# [554]	validation_0-auc:0.999725	validation_1-auc:0.982637
# [555]	validation_0-auc:0.999727	validation_1-auc:0.982634
# [556]	validation_0-auc:0.999729	validation_1-auc:0.982628
# [557]	validation_0-auc:0.999732	validation_1-auc:0.98263
# [558]	validation_0-auc:0.999735	validation_1-auc:0.982638
# [559]	validation_0-auc:0.999736	validation_1-auc:0.982641
# [560]	validation_0-auc:0.999736	validation_1-auc:0.982637
# [561]	validation_0-auc:0.999738	validation_1-auc:0.982634
# [562]	validation_0-auc:0.99974	validation_1-auc:0.982634
# [563]	validation_0-auc:0.999744	validation_1-auc:0.982633
# [564]	validation_0-auc:0.999745	validation_1-auc:0.982633
# [565]	validation_0-auc:0.999748	validation_1-auc:0.982639
# [566]	validation_0-auc:0.999749	validation_1-auc:0.982642
# [567]	validation_0-auc:0.999753	validation_1-auc:0.982639
# [568]	validation_0-auc:0.999754	validation_1-auc:0.982642
# [569]	validation_0-auc:0.999756	validation_1-auc:0.982647
# [570]	validation_0-auc:0.999759	validation_1-auc:0.982642
# [571]	validation_0-auc:0.999762	validation_1-auc:0.982637
# [572]	validation_0-auc:0.999763	validation_1-auc:0.982639
# [573]	validation_0-auc:0.999767	validation_1-auc:0.982636
# [574]	validation_0-auc:0.99977	validation_1-auc:0.982636
# [575]	validation_0-auc:0.999771	validation_1-auc:0.982638
# [576]	validation_0-auc:0.999772	validation_1-auc:0.982636
# [577]	validation_0-auc:0.999774	validation_1-auc:0.982634
# [578]	validation_0-auc:0.999775	validation_1-auc:0.982633
# [579]	validation_0-auc:0.999776	validation_1-auc:0.982634
# [580]	validation_0-auc:0.999777	validation_1-auc:0.982634
# [581]	validation_0-auc:0.999778	validation_1-auc:0.982631
# [582]	validation_0-auc:0.999779	validation_1-auc:0.982629
# [583]	validation_0-auc:0.999781	validation_1-auc:0.982628
# [584]	validation_0-auc:0.999785	validation_1-auc:0.982629
# [585]	validation_0-auc:0.999787	validation_1-auc:0.982627
# [586]	validation_0-auc:0.999788	validation_1-auc:0.982625
# [587]	validation_0-auc:0.999788	validation_1-auc:0.982623
# [588]	validation_0-auc:0.999789	validation_1-auc:0.982623
# Stopping. Best iteration:
# [488]	validation_0-auc:0.999503	validation_1-auc:0.982671
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.03, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=20000,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=420, silent=True, subsample=0.8)

# %%
sorted(zip(train_x.columns.values, models.feature_importances_), key=lambda x: x[1], reverse=True)
# Out:
# [('y_entry_19', 0.11827931),
#  ('x_entry_19', 0.045527466),
#  ('entry_hour_19', 0.039579768),
#  ('y_exit_18', 0.028969163),
#  ('duration_19', 0.026214631),
#  ('x_exit_18', 0.012290163),
#  ('y_entry_18', 0.01015353),
#  ('entry_minute_19', 0.006046941),
#  ('y_entry_17', 0.005836972),
#  ('y_exit_17', 0.0054184766),
#  ('x_exit_3', 0.004950177),
#  ('x_entry_18', 0.0048198737),
#  ('vmin_7', 0.004452624),
#  ('y_entry_16', 0.0043693576),
#  ('x_entry_17', 0.0043582167),
#  ('y_entry_13', 0.0043359944),
#  ('y_exit_3', 0.004331405),
#  ('exit_minute_19', 0.0043258774),
#  ('vmax_5', 0.004317841),
#  ('y_entry_15', 0.004277213),
#  ('vmin_6', 0.0041670823),
#  ('exit_hour_10', 0.0040657567),
#  ('y_entry_12', 0.0040165023),
#  ('x_exit_17', 0.0039712465),
#  ('entry_minute_5', 0.0039380398),
#  ('x_entry_2', 0.0039190133),
#  ('vmean_17', 0.0038993075),
#  ('vmean_16', 0.0038910958),
#  ('vmean_4', 0.0038870217),
#  ('y_entry_10', 0.00381014),
#  ('vmean_7', 0.003795267),
#  ('vmax_13', 0.0037929155),
#  ('x_entry_16', 0.0037673796),
#  ('y_exit_16', 0.0037671933),
#  ('vmax_6', 0.0037639805),
#  ('vmax_9', 0.0037436548),
#  ('exit_hour_12', 0.003729545),
#  ('x_entry_15', 0.003678253),
#  ('exit_second_7', 0.0036732415),
#  ('duration_7', 0.0036687215),
#  ('y_exit_9', 0.0036510122),
#  ('vmax_10', 0.0036364447),
#  ('y_entry_14', 0.0036063427),
#  ('entry_hour_12', 0.0036001909),
#  ('exit_hour_11', 0.0035464624),
#  ('y_exit_2', 0.0035384838),
#  ('x_entry_13', 0.0035353357),
#  ('y_entry_4', 0.0035122265),
#  ('vmean_6', 0.0035117054),
#  ('vmin_17', 0.0034928815),
#  ('entry_minute_4', 0.0034898568),
#  ('x_entry_6', 0.003465051),
#  ('vmean_18', 0.0034393126),
#  ('x_entry_12', 0.0034228875),
#  ('y_exit_15', 0.00341147),
#  ('entry_hour_11', 0.0033884847),
#  ('vmin_18', 0.0033604598),
#  ('x_exit_7', 0.0033534109),
#  ('vmean_12', 0.00334271),
#  ('duration_18', 0.0033344964),
#  ('vmin_16', 0.003330499),
#  ('y_exit_7', 0.0033039036),
#  ('x_exit_16', 0.003300075),
#  ('x_entry_8', 0.0032743304),
#  ('y_entry_5', 0.0032595685),
#  ('x_entry_14', 0.0032463737),
#  ('vmax_12', 0.0032436782),
#  ('exit_hour_9', 0.0032403274),
#  ('x_exit_4', 0.003231161),
#  ('y_entry_6', 0.0032303475),
#  ('vmin_15', 0.0032243023),
#  ('x_exit_2', 0.0032196152),
#  ('x_exit_8', 0.0032177249),
#  ('y_entry_11', 0.0032074952),
#  ('entry_hour_5', 0.0032067527),
#  ('y_entry_8', 0.003202195),
#  ('vmin_12', 0.0031988998),
#  ('exit_minute_3', 0.003191872),
#  ('vmax_18', 0.0031779762),
#  ('vmax_17', 0.0031773264),
#  ('entry_second_2', 0.0031751834),
#  ('exit_hour_18', 0.0031746493),
#  ('y_exit_13', 0.0031734738),
#  ('vmean_13', 0.0031527681),
#  ('x_exit_14', 0.0031439424),
#  ('x_entry_9', 0.0031438526),
#  ('exit_hour_16', 0.0031326225),
#  ('x_exit_13', 0.0031197006),
#  ('vmin_10', 0.0031073268),
#  ('entry_hour_10', 0.003091208),
#  ('exit_hour_17', 0.0030863644),
#  ('vmin_3', 0.0030778393),
#  ('x_exit_5', 0.0030661898),
#  ('vmean_10', 0.0030638732),
#  ('vmax_14', 0.0030626124),
#  ('entry_hour_17', 0.003055787),
#  ('exit_second_3', 0.0030546093),
#  ('y_exit_14', 0.0030350746),
#  ('x_exit_15', 0.003027772),
#  ('exit_minute_8', 0.003020566),
#  ('y_exit_6', 0.0030098944),
#  ('entry_hour_18', 0.003008366),
#  ('y_exit_12', 0.0030069007),
#  ('exit_second_14', 0.0030029113),
#  ('x_exit_12', 0.003002075),
#  ('exit_second_11', 0.0029978312),
#  ('vmean_11', 0.002994455),
#  ('y_exit_10', 0.002987675),
#  ('x_exit_10', 0.00297603),
#  ('exit_second_12', 0.0029668496),
#  ('exit_minute_5', 0.0029652086),
#  ('exit_hour_14', 0.0029651767),
#  ('y_exit_8', 0.0029601762),
#  ('duration_17', 0.002958251),
#  ('duration_15', 0.0029551806),
#  ('entry_hour_15', 0.0029500218),
#  ('vmean_15', 0.002945752),
#  ('vmax_15', 0.0029333169),
#  ('y_exit_11', 0.002930958),
#  ('entry_second_5', 0.0029210735),
#  ('exit_hour_15', 0.002917931),
#  ('vmax_16', 0.0029135246),
#  ('entry_hour_4', 0.0028937273),
#  ('duration_16', 0.002886762),
#  ('vmean_8', 0.0028853933),
#  ('entry_hour_16', 0.0028786822),
#  ('vmean_14', 0.0028754869),
#  ('duration_14', 0.0028717082),
#  ('x_entry_11', 0.002867336),
#  ('y_entry_9', 0.0028654123),
#  ('duration_13', 0.0028635724),
#  ('y_entry_7', 0.0028615189),
#  ('exit_minute_13', 0.0028563805),
#  ('x_exit_11', 0.0028533011),
#  ('entry_minute_9', 0.0028504725),
#  ('x_entry_10', 0.002849368),
#  ('entry_hour_9', 0.0028437707),
#  ('exit_minute_15', 0.0028424738),
#  ('exit_second_4', 0.0028404987),
#  ('y_exit_4', 0.002832833),
#  ('entry_hour_14', 0.0028315783),
#  ('exit_second_8', 0.002830162),
#  ('entry_hour_13', 0.0028224967),
#  ('entry_hour_7', 0.0028158547),
#  ('entry_minute_16', 0.0028059017),
#  ('entry_minute_14', 0.0028022653),
#  ('exit_hour_7', 0.0027964597),
#  ('entry_second_13', 0.00279542),
#  ('entry_minute_8', 0.0027886657),
#  ('duration_8', 0.0027843385),
#  ('vmin_5', 0.0027780384),
#  ('duration_10', 0.0027740195),
#  ('duration_12', 0.0027688171),
#  ('duration_9', 0.0027648953),
#  ('duration_3', 0.002759659),
#  ('exit_minute_18', 0.0027569712),
#  ('exit_second_17', 0.002743246),
#  ('entry_second_10', 0.0027415229),
#  ('entry_hour_8', 0.0027407345),
#  ('entry_second_12', 0.0027375452),
#  ('duration_6', 0.0027262056),
#  ('exit_second_16', 0.0027197732),
#  ('exit_second_13', 0.0027104947),
#  ('vmax_8', 0.0027076248),
#  ('exit_second_19', 0.0027006923),
#  ('entry_second_6', 0.0026952077),
#  ('entry_minute_10', 0.0026827676),
#  ('entry_minute_17', 0.002682233),
#  ('exit_minute_17', 0.0026810446),
#  ('entry_minute_11', 0.002673213),
#  ('entry_second_19', 0.002673198),
#  ('entry_second_16', 0.0026660506),
#  ('vmin_14', 0.0026635902),
#  ('exit_minute_16', 0.0026619278),
#  ('exit_hour_13', 0.0026555427),
#  ('exit_second_5', 0.0026523063),
#  ('exit_minute_9', 0.0026511224),
#  ('vmax_3', 0.0026484095),
#  ('entry_second_14', 0.0026466744),
#  ('y_exit_5', 0.0026445892),
#  ('duration_11', 0.0026342426),
#  ('entry_second_15', 0.0026246856),
#  ('entry_minute_15', 0.0026235462),
#  ('x_exit_9', 0.002618842),
#  ('exit_second_9', 0.0026143463),
#  ('duration_2', 0.0025995304),
#  ('x_entry_4', 0.002589128),
#  ('entry_second_17', 0.0025848553),
#  ('entry_minute_13', 0.0025836919),
#  ('exit_second_10', 0.0025762015),
#  ('x_entry_7', 0.0025743255),
#  ('exit_minute_12', 0.0025733039),
#  ('entry_second_11', 0.0025685027),
#  ('exit_hour_4', 0.0025670654),
#  ('exit_minute_14', 0.002565129),
#  ('entry_minute_18', 0.0025618868),
#  ('exit_minute_11', 0.002559728),
#  ('entry_second_7', 0.0025559103),
#  ('vmin_13', 0.0025512527),
#  ('exit_second_15', 0.0025424052),
#  ('entry_minute_12', 0.002540795),
#  ('vmean_9', 0.0025337054),
#  ('exit_second_18', 0.0025266425),
#  ('y_entry_3', 0.002524184),
#  ('entry_second_18', 0.0025137572),
#  ('entry_minute_7', 0.0025083444),
#  ('vmin_11', 0.0025057192),
#  ('entry_minute_3', 0.0024872203),
#  ('exit_minute_7', 0.0024692724),
#  ('exit_second_6', 0.0024548005),
#  ('x_exit_6', 0.0024390717),
#  ('exit_hour_8', 0.0024387555),
#  ('entry_second_9', 0.0024343862),
#  ('exit_minute_6', 0.0024257072),
#  ('exit_minute_10', 0.0024224874),
#  ('exit_hour_3', 0.0023930739),
#  ('vmax_4', 0.0023800898),
#  ('vmax_11', 0.0023584273),
#  ('entry_second_3', 0.0023532861),
#  ('vmax_7', 0.0023235383),
#  ('entry_minute_6', 0.0023027284),
#  ('exit_minute_0', 0.0022953704),
#  ('entry_second_8', 0.0022935632),
#  ('x_entry_3', 0.0022375109),
#  ('entry_hour_6', 0.0022327178),
#  ('vmin_8', 0.002229744),
#  ('exit_minute_4', 0.0022215256),
#  ('duration_5', 0.002201518),
#  ('vmin_9', 0.0021482348),
#  ('entry_second_4', 0.0020984246),
#  ('x_entry_5', 0.0020738891),
#  ('exit_hour_6', 0.0020211462),
#  ('exit_hour_5', 0.0019979104),
#  ('vmax_2', 0.0019647328),
#  ('entry_minute_0', 0.0018711934),
#  ('exit_minute_1', 0.0018082996),
#  ('y_exit_0', 0.0017058087),
#  ('x_exit_1', 0.0016383025),
#  ('duration_4', 0.0016294642),
#  ('exit_hour_2', 0.0015946538),
#  ('exit_hour_1', 0.0015697228),
#  ('exit_minute_2', 0.0014984559),
#  ('entry_minute_2', 0.0014366191),
#  ('y_entry_1', 0.0014036711),
#  ('y_entry_2', 0.0012429334),
#  ('entry_hour_3', 0.0009127926),
#  ('y_exit_1', 0.00085971283),
#  ('exit_second_2', 0.00081707654),
#  ('vmin_2', 0.0007556941),
#  ('vmin_4', 0.0006396889),
#  ('entry_hour_1', 0.00060025323),
#  ('y_entry_0', 0.0005349585),
#  ('x_entry_0', 0.000510648),
#  ('vmax_0', 0.00050912064),
#  ('exit_second_0', 0.0005054295),
#  ('duration_0', 0.0005028839),
#  ('x_entry_1', 0.0004702238),
#  ('entry_second_1', 0.0004464988),
#  ('x_exit_0', 0.0004447593),
#  ('duration_1', 0.00041824262),
#  ('entry_second_0', 0.00031191277),
#  ('exit_second_1', 0.00028116186),
#  ('vmin_0', 0.0),
#  ('vmean_0', 0.0),
#  ('entry_hour_0', 0.0),
#  ('exit_hour_0', 0.0),
#  ('vmax_1', 0.0),
#  ('vmin_1', 0.0),
#  ('vmean_1', 0.0),
#  ('entry_minute_1', 0.0),
#  ('vmean_2', 0.0),
#  ('entry_hour_2', 0.0),
#  ('vmean_3', 0.0),
#  ('vmean_5', 0.0),
#  ('exit_hour_19', 0.0)]

# %%
pred_y = models.predict(test_x)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
(pred_y==test_y).sum()/test_y.count()
# Out:
# 0.9411479506209675

# %%
models2 = xgb.XGBClassifier(max_depth=10, learning_rate=0.03, n_estimators=488, n_jobs=-1,
                           subsample=0.8, colsample_bytree=0.8, seed=420)

# %%
models2.fit(X, Y, eval_metric='auc', eval_set=[(X, Y)])
# Out:
# [0]	validation_0-auc:0.982064
# [1]	validation_0-auc:0.984131
# [2]	validation_0-auc:0.983687
# [3]	validation_0-auc:0.983352
# [4]	validation_0-auc:0.982387
# [5]	validation_0-auc:0.983898
# [6]	validation_0-auc:0.984237
# [7]	validation_0-auc:0.98484
# [8]	validation_0-auc:0.984562
# [9]	validation_0-auc:0.985143
# [10]	validation_0-auc:0.985611
# [11]	validation_0-auc:0.986041
# [12]	validation_0-auc:0.986351
# [13]	validation_0-auc:0.986667
# [14]	validation_0-auc:0.986602
# [15]	validation_0-auc:0.986897
# [16]	validation_0-auc:0.987095
# [17]	validation_0-auc:0.987283
# [18]	validation_0-auc:0.987361
# [19]	validation_0-auc:0.987561
# [20]	validation_0-auc:0.98759
# [21]	validation_0-auc:0.987479
# [22]	validation_0-auc:0.987663
# [23]	validation_0-auc:0.98753
# [24]	validation_0-auc:0.987672
# [25]	validation_0-auc:0.987734
# [26]	validation_0-auc:0.987657
# [27]	validation_0-auc:0.987835
# [28]	validation_0-auc:0.988052
# [29]	validation_0-auc:0.988209
# [30]	validation_0-auc:0.988252
# [31]	validation_0-auc:0.988393
# [32]	validation_0-auc:0.98844
# [33]	validation_0-auc:0.988592
# [34]	validation_0-auc:0.98857
# [35]	validation_0-auc:0.988566
# [36]	validation_0-auc:0.988546
# [37]	validation_0-auc:0.98871
# [38]	validation_0-auc:0.988648
# [39]	validation_0-auc:0.988815
# [40]	validation_0-auc:0.988859
# [41]	validation_0-auc:0.988991
# [42]	validation_0-auc:0.989141
# [43]	validation_0-auc:0.989213
# [44]	validation_0-auc:0.989273
# [45]	validation_0-auc:0.989395
# [46]	validation_0-auc:0.989492
# [47]	validation_0-auc:0.989617
# [48]	validation_0-auc:0.989711
# [49]	validation_0-auc:0.989754
# [50]	validation_0-auc:0.989886
# [51]	validation_0-auc:0.989981
# [52]	validation_0-auc:0.990082
# [53]	validation_0-auc:0.990067
# [54]	validation_0-auc:0.990148
# [55]	validation_0-auc:0.990241
# [56]	validation_0-auc:0.990331
# [57]	validation_0-auc:0.990413
# [58]	validation_0-auc:0.99048
# [59]	validation_0-auc:0.990557
# [60]	validation_0-auc:0.990625
# [61]	validation_0-auc:0.990712
# [62]	validation_0-auc:0.990748
# [63]	validation_0-auc:0.990813
# [64]	validation_0-auc:0.990902
# [65]	validation_0-auc:0.990917
# [66]	validation_0-auc:0.991006
# [67]	validation_0-auc:0.991091
# [68]	validation_0-auc:0.991167
# [69]	validation_0-auc:0.991219
# [70]	validation_0-auc:0.991238
# [71]	validation_0-auc:0.991277
# [72]	validation_0-auc:0.991373
# [73]	validation_0-auc:0.991443
# [74]	validation_0-auc:0.991532
# [75]	validation_0-auc:0.991613
# [76]	validation_0-auc:0.991674
# [77]	validation_0-auc:0.991747
# [78]	validation_0-auc:0.991801
# [79]	validation_0-auc:0.991823
# [80]	validation_0-auc:0.991883
# [81]	validation_0-auc:0.991884
# [82]	validation_0-auc:0.991944
# [83]	validation_0-auc:0.991978
# [84]	validation_0-auc:0.992013
# [85]	validation_0-auc:0.992076
# [86]	validation_0-auc:0.9921
# [87]	validation_0-auc:0.992172
# [88]	validation_0-auc:0.992241
# [89]	validation_0-auc:0.992297
# [90]	validation_0-auc:0.992378
# [91]	validation_0-auc:0.992392
# [92]	validation_0-auc:0.992459
# [93]	validation_0-auc:0.992522
# [94]	validation_0-auc:0.992587
# [95]	validation_0-auc:0.99263
# [96]	validation_0-auc:0.992674
# [97]	validation_0-auc:0.992717
# [98]	validation_0-auc:0.992752
# [99]	validation_0-auc:0.992783
# [100]	validation_0-auc:0.992841
# [101]	validation_0-auc:0.992903
# [102]	validation_0-auc:0.992953
# [103]	validation_0-auc:0.992985
# [104]	validation_0-auc:0.993049
# [105]	validation_0-auc:0.993082
# [106]	validation_0-auc:0.993144
# [107]	validation_0-auc:0.993202
# [108]	validation_0-auc:0.993255
# [109]	validation_0-auc:0.993309
# [110]	validation_0-auc:0.993365
# [111]	validation_0-auc:0.993416
# [112]	validation_0-auc:0.993474
# [113]	validation_0-auc:0.993522
# [114]	validation_0-auc:0.99356
# [115]	validation_0-auc:0.993609
# [116]	validation_0-auc:0.993649
# [117]	validation_0-auc:0.993683
# [118]	validation_0-auc:0.993728
# [119]	validation_0-auc:0.993766
# [120]	validation_0-auc:0.993808
# [121]	validation_0-auc:0.993847
# [122]	validation_0-auc:0.993873
# [123]	validation_0-auc:0.993898
# [124]	validation_0-auc:0.99393
# [125]	validation_0-auc:0.993954
# [126]	validation_0-auc:0.993994
# [127]	validation_0-auc:0.994029
# [128]	validation_0-auc:0.994062
# [129]	validation_0-auc:0.994101
# [130]	validation_0-auc:0.994132
# [131]	validation_0-auc:0.994172
# [132]	validation_0-auc:0.994215
# [133]	validation_0-auc:0.994248
# [134]	validation_0-auc:0.99428
# [135]	validation_0-auc:0.994312
# [136]	validation_0-auc:0.994344
# [137]	validation_0-auc:0.994384
# [138]	validation_0-auc:0.994419
# [139]	validation_0-auc:0.994454
# [140]	validation_0-auc:0.994479
# [141]	validation_0-auc:0.994505
# [142]	validation_0-auc:0.994522
# [143]	validation_0-auc:0.994558
# [144]	validation_0-auc:0.994587
# [145]	validation_0-auc:0.99461
# [146]	validation_0-auc:0.994645
# [147]	validation_0-auc:0.994676
# [148]	validation_0-auc:0.994704
# [149]	validation_0-auc:0.994737
# [150]	validation_0-auc:0.994776
# [151]	validation_0-auc:0.994807
# [152]	validation_0-auc:0.994841
# [153]	validation_0-auc:0.994881
# [154]	validation_0-auc:0.994912
# [155]	validation_0-auc:0.994941
# [156]	validation_0-auc:0.994977
# [157]	validation_0-auc:0.995015
# [158]	validation_0-auc:0.995042
# [159]	validation_0-auc:0.99507
# [160]	validation_0-auc:0.995121
# [161]	validation_0-auc:0.995145
# [162]	validation_0-auc:0.995191
# [163]	validation_0-auc:0.995234
# [164]	validation_0-auc:0.99526
# [165]	validation_0-auc:0.995297
# [166]	validation_0-auc:0.995323
# [167]	validation_0-auc:0.995352
# [168]	validation_0-auc:0.995372
# [169]	validation_0-auc:0.995396
# [170]	validation_0-auc:0.995418
# [171]	validation_0-auc:0.995446
# [172]	validation_0-auc:0.995459
# [173]	validation_0-auc:0.995487
# [174]	validation_0-auc:0.995509
# [175]	validation_0-auc:0.995528
# [176]	validation_0-auc:0.995562
# [177]	validation_0-auc:0.995598
# [178]	validation_0-auc:0.99563
# [179]	validation_0-auc:0.995657
# [180]	validation_0-auc:0.995674
# [181]	validation_0-auc:0.995698
# [182]	validation_0-auc:0.995731
# [183]	validation_0-auc:0.995752
# [184]	validation_0-auc:0.995782
# [185]	validation_0-auc:0.995803
# [186]	validation_0-auc:0.995816
# [187]	validation_0-auc:0.995834
# [188]	validation_0-auc:0.995856
# [189]	validation_0-auc:0.99587
# [190]	validation_0-auc:0.99589
# [191]	validation_0-auc:0.995915
# [192]	validation_0-auc:0.995941
# [193]	validation_0-auc:0.995957
# [194]	validation_0-auc:0.99599
# [195]	validation_0-auc:0.996012
# [196]	validation_0-auc:0.996034
# [197]	validation_0-auc:0.996043
# [198]	validation_0-auc:0.996072
# [199]	validation_0-auc:0.996086
# [200]	validation_0-auc:0.996101
# [201]	validation_0-auc:0.99612
# [202]	validation_0-auc:0.996135
# [203]	validation_0-auc:0.996166
# [204]	validation_0-auc:0.996181
# [205]	validation_0-auc:0.996193
# [206]	validation_0-auc:0.996211
# [207]	validation_0-auc:0.996227
# [208]	validation_0-auc:0.99625
# [209]	validation_0-auc:0.996274
# [210]	validation_0-auc:0.996292
# [211]	validation_0-auc:0.99631
# [212]	validation_0-auc:0.996319
# [213]	validation_0-auc:0.996345
# [214]	validation_0-auc:0.996374
# [215]	validation_0-auc:0.996401
# [216]	validation_0-auc:0.996423
# [217]	validation_0-auc:0.99644
# [218]	validation_0-auc:0.996473
# [219]	validation_0-auc:0.996486
# [220]	validation_0-auc:0.996499
# [221]	validation_0-auc:0.996519
# [222]	validation_0-auc:0.996533
# [223]	validation_0-auc:0.996555
# [224]	validation_0-auc:0.996577
# [225]	validation_0-auc:0.99659
# [226]	validation_0-auc:0.996605
# [227]	validation_0-auc:0.996617
# [228]	validation_0-auc:0.996641
# [229]	validation_0-auc:0.996654
# [230]	validation_0-auc:0.996663
# [231]	validation_0-auc:0.996675
# [232]	validation_0-auc:0.996691
# [233]	validation_0-auc:0.996696
# [234]	validation_0-auc:0.996725
# [235]	validation_0-auc:0.996735
# [236]	validation_0-auc:0.996758
# [237]	validation_0-auc:0.996775
# [238]	validation_0-auc:0.996786
# [239]	validation_0-auc:0.996797
# [240]	validation_0-auc:0.996803
# [241]	validation_0-auc:0.996815
# [242]	validation_0-auc:0.996842
# [243]	validation_0-auc:0.996871
# [244]	validation_0-auc:0.996885
# [245]	validation_0-auc:0.996896
# [246]	validation_0-auc:0.996918
# [247]	validation_0-auc:0.996929
# [248]	validation_0-auc:0.996942
# [249]	validation_0-auc:0.996956
# [250]	validation_0-auc:0.996969
# [251]	validation_0-auc:0.996985
# [252]	validation_0-auc:0.996996
# [253]	validation_0-auc:0.997006
# [254]	validation_0-auc:0.997019
# [255]	validation_0-auc:0.997044
# [256]	validation_0-auc:0.997055
# [257]	validation_0-auc:0.997061
# [258]	validation_0-auc:0.997083
# [259]	validation_0-auc:0.99709
# [260]	validation_0-auc:0.997104
# [261]	validation_0-auc:0.997115
# [262]	validation_0-auc:0.99713
# [263]	validation_0-auc:0.997142
# [264]	validation_0-auc:0.997155
# [265]	validation_0-auc:0.99716
# [266]	validation_0-auc:0.997169
# [267]	validation_0-auc:0.997178
# [268]	validation_0-auc:0.997188
# [269]	validation_0-auc:0.997206
# [270]	validation_0-auc:0.997218
# [271]	validation_0-auc:0.997225
# [272]	validation_0-auc:0.997239
# [273]	validation_0-auc:0.997257
# [274]	validation_0-auc:0.997266
# [275]	validation_0-auc:0.997271
# [276]	validation_0-auc:0.997278
# [277]	validation_0-auc:0.997283
# [278]	validation_0-auc:0.997285
# [279]	validation_0-auc:0.997304
# [280]	validation_0-auc:0.997322
# [281]	validation_0-auc:0.997338
# [282]	validation_0-auc:0.997348
# [283]	validation_0-auc:0.997359
# [284]	validation_0-auc:0.997367
# [285]	validation_0-auc:0.997381
# [286]	validation_0-auc:0.997413
# [287]	validation_0-auc:0.997429
# [288]	validation_0-auc:0.997434
# [289]	validation_0-auc:0.997442
# [290]	validation_0-auc:0.99746
# [291]	validation_0-auc:0.997473
# [292]	validation_0-auc:0.997479
# [293]	validation_0-auc:0.997491
# [294]	validation_0-auc:0.997503
# [295]	validation_0-auc:0.997508
# [296]	validation_0-auc:0.997528
# [297]	validation_0-auc:0.997542
# [298]	validation_0-auc:0.997553
# [299]	validation_0-auc:0.997581
# [300]	validation_0-auc:0.997613
# [301]	validation_0-auc:0.99762
# [302]	validation_0-auc:0.997636
# [303]	validation_0-auc:0.997656
# [304]	validation_0-auc:0.997666
# [305]	validation_0-auc:0.99767
# [306]	validation_0-auc:0.99768
# [307]	validation_0-auc:0.997687
# [308]	validation_0-auc:0.997701
# [309]	validation_0-auc:0.997716
# [310]	validation_0-auc:0.997729
# [311]	validation_0-auc:0.997737
# [312]	validation_0-auc:0.997747
# [313]	validation_0-auc:0.997781
# [314]	validation_0-auc:0.997794
# [315]	validation_0-auc:0.997811
# [316]	validation_0-auc:0.997821
# [317]	validation_0-auc:0.99783
# [318]	validation_0-auc:0.997851
# [319]	validation_0-auc:0.997859
# [320]	validation_0-auc:0.997871
# [321]	validation_0-auc:0.997894
# [322]	validation_0-auc:0.997912
# [323]	validation_0-auc:0.997921
# [324]	validation_0-auc:0.997935
# [325]	validation_0-auc:0.997947
# [326]	validation_0-auc:0.997962
# [327]	validation_0-auc:0.997968
# [328]	validation_0-auc:0.997972
# [329]	validation_0-auc:0.997985
# [330]	validation_0-auc:0.997998
# [331]	validation_0-auc:0.998003
# [332]	validation_0-auc:0.998012
# [333]	validation_0-auc:0.998017
# [334]	validation_0-auc:0.998037
# [335]	validation_0-auc:0.998045
# [336]	validation_0-auc:0.99805
# [337]	validation_0-auc:0.998059
# [338]	validation_0-auc:0.998069
# [339]	validation_0-auc:0.99808
# [340]	validation_0-auc:0.998082
# [341]	validation_0-auc:0.998095
# [342]	validation_0-auc:0.998103
# [343]	validation_0-auc:0.998105
# [344]	validation_0-auc:0.998117
# [345]	validation_0-auc:0.998124
# [346]	validation_0-auc:0.998131
# [347]	validation_0-auc:0.998147
# [348]	validation_0-auc:0.998157
# [349]	validation_0-auc:0.998166
# [350]	validation_0-auc:0.998173
# [351]	validation_0-auc:0.998182
# [352]	validation_0-auc:0.998199
# [353]	validation_0-auc:0.998223
# [354]	validation_0-auc:0.998231
# [355]	validation_0-auc:0.998253
# [356]	validation_0-auc:0.998256
# [357]	validation_0-auc:0.998259
# [358]	validation_0-auc:0.998281
# [359]	validation_0-auc:0.998294
# [360]	validation_0-auc:0.998299
# [361]	validation_0-auc:0.998321
# [362]	validation_0-auc:0.998327
# [363]	validation_0-auc:0.998339
# [364]	validation_0-auc:0.998344
# [365]	validation_0-auc:0.998357
# [366]	validation_0-auc:0.998385
# [367]	validation_0-auc:0.998389
# [368]	validation_0-auc:0.998402
# [369]	validation_0-auc:0.998416
# [370]	validation_0-auc:0.998436
# [371]	validation_0-auc:0.998437
# [372]	validation_0-auc:0.998447
# [373]	validation_0-auc:0.998463
# [374]	validation_0-auc:0.998468
# [375]	validation_0-auc:0.998473
# [376]	validation_0-auc:0.998479
# [377]	validation_0-auc:0.998493
# [378]	validation_0-auc:0.998499
# [379]	validation_0-auc:0.998506
# [380]	validation_0-auc:0.998522
# [381]	validation_0-auc:0.998533
# [382]	validation_0-auc:0.998535
# [383]	validation_0-auc:0.998541
# [384]	validation_0-auc:0.998548
# [385]	validation_0-auc:0.998552
# [386]	validation_0-auc:0.998556
# [387]	validation_0-auc:0.99858
# [388]	validation_0-auc:0.998594
# [389]	validation_0-auc:0.9986
# [390]	validation_0-auc:0.998608
# [391]	validation_0-auc:0.998612
# [392]	validation_0-auc:0.998618
# [393]	validation_0-auc:0.998626
# [394]	validation_0-auc:0.998631
# [395]	validation_0-auc:0.998639
# [396]	validation_0-auc:0.998642
# [397]	validation_0-auc:0.998646
# [398]	validation_0-auc:0.998658
# [399]	validation_0-auc:0.998661
# [400]	validation_0-auc:0.998669
# [401]	validation_0-auc:0.998675
# [402]	validation_0-auc:0.998686
# [403]	validation_0-auc:0.998688
# [404]	validation_0-auc:0.998699
# [405]	validation_0-auc:0.998702
# [406]	validation_0-auc:0.998714
# [407]	validation_0-auc:0.998725
# [408]	validation_0-auc:0.998735
# [409]	validation_0-auc:0.998743
# [410]	validation_0-auc:0.998751
# [411]	validation_0-auc:0.998759
# [412]	validation_0-auc:0.998771
# [413]	validation_0-auc:0.998782
# [414]	validation_0-auc:0.998793
# [415]	validation_0-auc:0.998798
# [416]	validation_0-auc:0.998803
# [417]	validation_0-auc:0.998815
# [418]	validation_0-auc:0.998824
# [419]	validation_0-auc:0.998831
# [420]	validation_0-auc:0.998834
# [421]	validation_0-auc:0.998836
# [422]	validation_0-auc:0.998843
# [423]	validation_0-auc:0.998856
# [424]	validation_0-auc:0.998864
# [425]	validation_0-auc:0.998871
# [426]	validation_0-auc:0.998877
# [427]	validation_0-auc:0.998885
# [428]	validation_0-auc:0.99889
# [429]	validation_0-auc:0.998893
# [430]	validation_0-auc:0.998895
# [431]	validation_0-auc:0.998903
# [432]	validation_0-auc:0.998908
# [433]	validation_0-auc:0.998917
# [434]	validation_0-auc:0.998919
# [435]	validation_0-auc:0.998922
# [436]	validation_0-auc:0.998932
# [437]	validation_0-auc:0.998935
# [438]	validation_0-auc:0.998948
# [439]	validation_0-auc:0.998954
# [440]	validation_0-auc:0.998961
# [441]	validation_0-auc:0.998973
# [442]	validation_0-auc:0.998979
# [443]	validation_0-auc:0.998981
# [444]	validation_0-auc:0.998985
# [445]	validation_0-auc:0.998992
# [446]	validation_0-auc:0.999001
# [447]	validation_0-auc:0.99901
# [448]	validation_0-auc:0.999015
# [449]	validation_0-auc:0.999017
# [450]	validation_0-auc:0.999028
# [451]	validation_0-auc:0.999034
# [452]	validation_0-auc:0.999039
# [453]	validation_0-auc:0.999041
# [454]	validation_0-auc:0.999049
# [455]	validation_0-auc:0.999054
# [456]	validation_0-auc:0.999057
# [457]	validation_0-auc:0.999065
# [458]	validation_0-auc:0.999069
# [459]	validation_0-auc:0.999071
# [460]	validation_0-auc:0.999075
# [461]	validation_0-auc:0.999085
# [462]	validation_0-auc:0.999089
# [463]	validation_0-auc:0.999096
# [464]	validation_0-auc:0.999103
# [465]	validation_0-auc:0.999107
# [466]	validation_0-auc:0.999111
# [467]	validation_0-auc:0.999113
# [468]	validation_0-auc:0.999122
# [469]	validation_0-auc:0.99913
# [470]	validation_0-auc:0.999132
# [471]	validation_0-auc:0.999144
# [472]	validation_0-auc:0.999148
# [473]	validation_0-auc:0.999156
# [474]	validation_0-auc:0.999161
# [475]	validation_0-auc:0.999162
# [476]	validation_0-auc:0.999164
# [477]	validation_0-auc:0.999169
# [478]	validation_0-auc:0.999175
# [479]	validation_0-auc:0.999185
# [480]	validation_0-auc:0.999189
# [481]	validation_0-auc:0.999193
# [482]	validation_0-auc:0.999196
# [483]	validation_0-auc:0.999204
# [484]	validation_0-auc:0.999207
# [485]	validation_0-auc:0.999209
# [486]	validation_0-auc:0.999213
# [487]	validation_0-auc:0.999215
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0, learning_rate=0.03, max_delta_step=0,
#        max_depth=10, min_child_weight=1, missing=None, n_estimators=488,
#        n_jobs=-1, nthread=None, objective='binary:logistic',
#        random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#        seed=420, silent=True, subsample=0.8)

# %%
X[:5]
# Out:
#    vmax_0  vmin_0  vmean_0  x_entry_0  y_entry_0  x_exit_0  y_exit_0  \
# 0     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 1     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 2     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 3     NaN     NaN      NaN        NaN        NaN       NaN       NaN
# 4     NaN     NaN      NaN        NaN        NaN       NaN       NaN
#
#    duration_0  entry_hour_0  entry_minute_0       ...        exit_second_18  \
# 0         NaN           NaN             NaN       ...                   9.0
# 1         NaN           NaN             NaN       ...                  14.0
# 2         NaN           NaN             NaN       ...                   8.0
# 3         NaN           NaN             NaN       ...                   1.0
# 4         NaN           NaN             NaN       ...                  54.0
#
#      x_entry_19    y_entry_19  duration_19  entry_hour_19  entry_minute_19  \
# 0  3.744945e+06 -1.928183e+07          962             15                2
# 1  3.749088e+06 -1.926605e+07         1756             15                0
# 2  3.758738e+06 -1.937594e+07         2716             14               34
# 3  3.767866e+06 -1.917797e+07            0             15               28
# 4  3.747641e+06 -1.922695e+07            0             15                8
#
#    entry_second_19  exit_hour_19  exit_minute_19  exit_second_19
# 0               31            15              18              33
# 1               32            15              29              48
# 2               35            15              19              51
# 3               54            15              28              54
# 4                5            15               8               5
#
# [5 rows x 275 columns]

# %% [markdown]
# # 3. Make Prediction

# %%
test = pd.read_csv("data/raw/data_test.csv")

# %%
test['time_entry'] = pd.to_datetime(test['time_entry'], format='%H:%M:%S')
test['time_exit']  = pd.to_datetime(test['time_exit'], format='%H:%M:%S')

# %%
test['duration'] = (test['time_exit'] - test['time_entry']).dt.total_seconds().astype(int)

# %%
test['entry_hour'] = test['time_entry'].dt.hour
test['entry_minute'] = test['time_entry'].dt.minute
test['entry_second'] = test['time_entry'].dt.second
test['exit_hour'] = test['time_exit'].dt.hour
test['exit_minute'] = test['time_exit'].dt.minute
test['exit_second'] = test['time_exit'].dt.second

# %%
tgroups = test.groupby("hash")

# %%
tdependence = []
pbar = tqdm(total=len(tgroups))
for name, g in tgroups:
    pbar.update(1)
    available = [g.iloc[i] for i in range(len(g))]
    nanpaddin = [pd.Series([np.nan]*(20*len(test[:5].columns)-sum([len(x) for x in available])))]
    tdependence.append(pd.concat(nanpaddin+available, axis=0, ignore_index=True))    
pbar.close()
# Out:
# 100%|██████████| 33515/33515 [01:08<00:00, 490.47it/s]

# %%
test2 = pd.concat(tdependence, axis=1).T

# %%
test2.columns = [x + "_" + str(y) for y in range(20) for x in test.columns]

# %%
test2[:5]
# Out:
#   Unnamed: 0_0 hash_0 trajectory_id_0 time_entry_0 time_exit_0 vmax_0 vmin_0  \
# 0          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 1          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 2          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 3          NaN    NaN             NaN          NaN         NaN    NaN    NaN
# 4          NaN    NaN             NaN          NaN         NaN    NaN    NaN
#
#   vmean_0 x_entry_0 y_entry_0      ...         y_entry_19 x_exit_19 y_exit_19  \
# 0     NaN       NaN       NaN      ...       -1.91449e+07       NaN       NaN
# 1     NaN       NaN       NaN      ...       -1.93414e+07       NaN       NaN
# 2     NaN       NaN       NaN      ...       -1.92386e+07       NaN       NaN
# 3     NaN       NaN       NaN      ...        -1.9355e+07       NaN       NaN
# 4     NaN       NaN       NaN      ...       -1.91701e+07       NaN       NaN
#
#   duration_19 entry_hour_19 entry_minute_19 entry_second_19 exit_hour_19  \
# 0         420            15               3              32           15
# 1         107            15              29               9           15
# 2           0            15              26               8           15
# 3         407            15              35              18           15
# 4         667            14              54               7           15
#
#   exit_minute_19 exit_second_19
# 0             10             32
# 1             30             56
# 2             26              8
# 3             42              5
# 4              5             14
#
# [5 rows x 380 columns]

# %%
test2.to_csv('data/interim/data_test_concat.csv')

# %%
test2 = pd.read_csv("data/interim/data_test_concat.csv", index_col=False)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (2,3,4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
test2.shape
# Out:
# (33515, 381)

# %%
tname = test2['trajectory_id_19']

# %%
tX = test2.drop([x+str(y) for y in range(20) for x in ['Unnamed: 0_', 'hash_', 'trajectory_id_', 'time_entry_', 'time_exit_']] \
    + ['x_exit_19', 'y_exit_19','vmax_19', 'vmin_19', 'vmean_19'] + ['Unnamed: 0'], axis=1)
# X = X.fillna(0)

# %%
(X.shape, tX.shape)
# Out:
# ((134063, 275), (33515, 275))

# %%
pred_y = models2.predict(tX)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print(pred_y.sum(), pred_y.shape)
# Out:
# 8358 (33515,)

# %%
output = pd.DataFrame({'id': tname, 'target': pred_y.astype(int)})
output.to_csv('data/submissions/submission6.csv', index=False, columns=['id', 'target'])
